# %% [markdown]
# <a href="https://colab.research.google.com/github/gumurytv/bigdataCert/blob/main/%EB%B9%85%EB%B6%84%EA%B8%B0_%EC%8B%A4%EA%B8%B0_PART1_%EC%97%B0%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
menu=pd.Series(['비빔밥','김치찌개','된장찌개'])

# %%
menu
# Out:
# 0     비빔밥
# 1    김치찌개
# 2    된장찌개
# dtype: object

# %%
menu
# Out:
# 0     비빔밥
# 1    김치찌개
# 2    된장찌개
# dtype: object

# %%
price=pd.Series([10000,9000,8000])

# %%
price
# Out:
# 0    10000
# 1     9000
# 2     8000
# dtype: int64

# %%
df=pd.DataFrame({'메뉴':['비빔밥','김치찌개','된장찌개'],
                 '가격':[10000,9000,8000],
                 '원산지':['국내산','국내산','국내산']})

# %%
df
# Out:
#      메뉴     가격  원산지
# 0   비빔밥  10000  국내산
# 1  김치찌개   9000  국내산
# 2  된장찌개   8000  국내산

# %%
df['메뉴']
# Out:
# 0     비빔밥
# 1    김치찌개
# 2    된장찌개
# Name: 메뉴, dtype: object

# %%
df.'메뉴'
# Out:
#   File "/tmp/ipykernel_6607/2931634542.py", line 1
#     df.'메뉴'
#        ^
# SyntaxError: invalid syntax

# %%
df.메뉴
# Out:
# 0     비빔밥
# 1    김치찌개
# 2    된장찌개
# Name: 메뉴, dtype: object

# %%
df[['메뉴']]
# Out:
#      메뉴
# 0   비빔밥
# 1  김치찌개
# 2  된장찌개

# %%
df['메뉴']
# Out:
# 0     비빔밥
# 1    김치찌개
# 2    된장찌개
# Name: 메뉴, dtype: object

# %%
df[['메뉴','가격']]
# Out:
#      메뉴     가격
# 0   비빔밥  10000
# 1  김치찌개   9000
# 2  된장찌개   8000

# %%
cols=['메뉴','가격']

# %%
df[col]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6607/4021469211.py in <cell line: 0>()
# ----> 1 df[col]
#
# NameError: name 'col' is not defined

# %%
df[cols]
# Out:
#      메뉴     가격
# 0   비빔밥  10000
# 1  김치찌개   9000
# 2  된장찌개   8000

# %%
type[df]
# Out:
# type[     메뉴     가격  원산지
# 0   비빔밥  10000  국내산
# 1  김치찌개   9000  국내산
# 2  된장찌개   8000  국내산]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
print('df:',type(df))
# Out:
# df: <class 'pandas.core.frame.DataFrame'>

# %%
df=pd.DataFrame({
    '메뉴':['아메리카노','카페라떼','카페모카','카푸치노','에스프레소','밀크티','녹차'],
    '가격':[4500,5000,5500,5000,4000,5900,5300],
    '칼로리':[10,110,250,110,20,210,0]
})

# %%
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
df_to.csv('temp.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6607/3426648481.py in <cell line: 0>()
# ----> 1 df_to.csv('temp.csv')
#
# NameError: name 'df_to' is not defined

# %%
df.to_csv('temp.csv')

# %%
temp_df=pd.read_csv('temp.csv')

# %%
temp_df.head()
# Out:
#    Unnamed: 0     메뉴    가격  칼로리
# 0           0  아메리카노  4500   10
# 1           1   카페라떼  5000  110
# 2           2   카페모카  5500  250
# 3           3   카푸치노  5000  110
# 4           4  에스프레소  4000   20

# %%
df.to_csv('cafe.csv',index=False)

# %%
df=pd.read_csv('cafe.csv')

# %%
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
df.shape
# Out:
# (7, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      int64
#  2   칼로리     7 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 300.0+ bytes

# %%
df.corr(numeric=Ture)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6607/2361610131.py in <cell line: 0>()
# ----> 1 df.corr(numeric=Ture)
#
# NameError: name 'Ture' is not defined

# %%
df.corr(numeric_only=True)
# Out:
#            가격       칼로리
# 가격   1.000000  0.713227
# 칼로리  0.713227  1.000000

# %%
df_car=pd.DataFrame({'car':['Sedan','SUV','Sedan','SUV','SUV','SUV','Sedan','Sedan','Sedan','Sedan','Sedan'],
                  'size':['S','M','S','S','M','M','L','S','S','M','S']})

# %%
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
df_car
# Out:
#       car size
# 0   Sedan    S
# 1     SUV    M
# 2   Sedan    S
# 3     SUV    S
# 4     SUV    M
# 5     SUV    M
# 6   Sedan    L
# 7   Sedan    S
# 8   Sedan    S
# 9   Sedan    M
# 10  Sedan    S

# %%
df_car.head(3)
# Out:
#      car size
# 0  Sedan    S
# 1    SUV    M
# 2  Sedan    S

# %%
df_car.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_6607/4189116229.py in <cell line: 0>()
# ----> 1 df_car.unique()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
df_car.nunique()
# Out:
# car     2
# size    3
# dtype: int64

# %%
print(df_car['car'].unique())
# Out:
# ['Sedan' 'SUV']

# %%
print(df_car['size'].unique())
# Out:
# ['S' 'M' 'L']

# %%
df_car['car'].value_counts()
# Out:
# car
# Sedan    7
# SUV      4
# Name: count, dtype: int64

# %%
df.value_counts()
# Out:
# 메뉴     가격    칼로리
# 녹차     5300  0      1
# 밀크티    5900  210    1
# 아메리카노  4500  10     1
# 에스프레소  4000  20     1
# 카페라떼   5000  110    1
# 카페모카   5500  250    1
# 카푸치노   5000  110    1
# Name: count, dtype: int64

# %%
df_car.describe()
# Out:
#           car size
# count      11   11
# unique      2    3
# top     Sedan    S
# freq        7    6

# %%
df.describe()
# Out:
#                 가격         칼로리
# count     7.000000    7.000000
# mean   5028.571429  101.428571
# std     631.702160   99.402980
# min    4000.000000    0.000000
# 25%    4750.000000   15.000000
# 50%    5000.000000  110.000000
# 75%    5400.000000  160.000000
# max    5900.000000  250.000000

# %%
df_car.describe()
# Out:
#           car size
# count      11   11
# unique      2    3
# top     Sedan    S
# freq        7    6

# %%
df.describe(include='0')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_6607/2573707912.py in <cell line: 0>()
# ----> 1 df.describe(include='0')
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in describe(self, percentiles, include, exclude)
#   11974         max            NaN      3.0
#   11975         """
# > 11976         return describe_ndframe(
#   11977             obj=self,
#   11978             include=include,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/methods/describe.py in describe_ndframe(obj, include, exclude, percentiles)
#      95         )
#      96
# ---> 97     result = describer.describe(percentiles=percentiles)
#      98     return cast(NDFrameT, result)
#      99
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/methods/describe.py in describe(self, percentiles)
#     165
#     166     def describe(self, percentiles: Sequence[float] | np.ndarray) -> DataFrame:
# --> 167         data = self._select_data()
#     168
#     169         ldesc: list[Series] = []
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/methods/describe.py in _select_data(self)
#     195             data = self.obj
#     196         else:
# --> 197             data = self.obj.select_dtypes(
#     198                 include=self.include,
#     199                 exclude=self.exclude,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in select_dtypes(self, include, exclude)
#    5058             return frozenset(converted_dtypes)
#    5059
# -> 5060         include = check_int_infer_dtype(include)
#    5061         exclude = check_int_infer_dtype(exclude)
#    5062
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in check_int_infer_dtype(dtypes)
#    5055                     converted_dtypes.extend([np.float64, np.float32])
#    5056                 else:
# -> 5057                     converted_dtypes.append(infer_dtype_from_object(dtype))
#    5058             return frozenset(converted_dtypes)
#    5059
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/dtypes/common.py in infer_dtype_from_object(dtype)
#    1540             pass
#    1541
# -> 1542     return infer_dtype_from_object(np.dtype(dtype))
#    1543
#    1544
#
# TypeError: data type '' not understood

# %%
data={
    '메뉴':['아메리카노','카페라떼','카페모카','카푸치노','에스프레소','밀크티','녹차'],
    '가격':[4500,5000,5500,5000,4000,5900,5300],
    '칼로리':['10','110','250','110','20','210','0']
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
data
# Out:
# {'메뉴': ['아메리카노', '카페라떼', '카페모카', '카푸치노', '에스프레소', '밀크티', '녹차'],
#  '가격': [4500, 5000, 5500, 5000, 4000, 5900, 5300],
#  '칼로리': ['10', '110', '250', '110', '20', '210', '0']}

# %%
df['가격']=df['가격'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      int64
#  2   칼로리     7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 300.0+ bytes

# %%
df['칼로리']=df['칼로리'].astype('float')

# %%
ㅇㄹ
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6607/240820798.py in <cell line: 0>()
# ----> 1 ㅇㄹ
#
# NameError: name 'ᄋᄅ' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      int64
#  2   칼로리     7 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 300.0+ bytes

# %%
df=pd.read_csv('cafe.csv')

# %%
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
df['new']=0

# %%
df.head()
# Out:
#       메뉴    가격  칼로리  new
# 0  아메리카노  4500   10    0
# 1   카페라떼  5000  110    0
# 2   카페모카  5500  250    0
# 3   카푸치노  5000  110    0
# 4  에스프레소  4000   20    0

# %%
discount=0.2

# %%
df['할인가']=df['가격']*(1-discount)

# %%
df
# Out:
#       메뉴    가격  칼로리  new     할인가
# 0  아메리카노  4500   10    0  3600.0
# 1   카페라떼  5000  110    0  4000.0
# 2   카페모카  5500  250    0  4400.0
# 3   카푸치노  5000  110    0  4000.0
# 4  에스프레소  4000   20    0  3200.0
# 5    밀크티  5900  210    0  4720.0
# 6     녹차  5300    0    0  4240.0

# %%
df=pd.read_csv('cafe.csv')

# %%
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
df.drop(1,axis=0,inplace=True)

# %%
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
df=df.drop('메뉴',axis=1)

# %%
df
# Out:
#      가격  칼로리
# 0  4500   10
# 2  5500  250
# 3  5000  110
# 4  4000   20
# 5  5900  210
# 6  5300    0

# %%
df=pd.read_csv('cafe.csv')

# %%
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
df.loc[0]
# Out:
# 메뉴     아메리카노
# 가격      4500
# 칼로리       10
# Name: 0, dtype: object

# %%
df.loc[1,'가격']
# Out:
# np.int64(5000)

# %%
df.loc[:,'가격']
# Out:
# 0    4500
# 1    5000
# 2    5500
# 3    5000
# 4    4000
# 5    5900
# 6    5300
# Name: 가격, dtype: int64

# %%
df.loc[2,'메뉴':'칼로리']
# Out:
# 메뉴     카페모카
# 가격     5500
# 칼로리     250
# Name: 2, dtype: object

# %%
df.loc[2,['메뉴','칼로리']]
# Out:
# 메뉴     카페모카
# 칼로리     250
# Name: 2, dtype: object

# %%
df.loc[1:3,['메뉴','칼로리']]
# Out:
#      메뉴  칼로리
# 1  카페라떼  110
# 2  카페모카  250
# 3  카푸치노  110
