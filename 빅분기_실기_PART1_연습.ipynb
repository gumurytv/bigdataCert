# %% [markdown]
# <a href="https://colab.research.google.com/github/gumurytv/bigdataCert/blob/main/%EB%B9%85%EB%B6%84%EA%B8%B0_%EC%8B%A4%EA%B8%B0_PART1_%EC%97%B0%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
menu=pd.Series(['비빔밥','김치찌개','된장찌개'])

# %%
menu
# Out:
# 0     비빔밥
# 1    김치찌개
# 2    된장찌개
# dtype: object

# %%
menu
# Out:
# 0     비빔밥
# 1    김치찌개
# 2    된장찌개
# dtype: object

# %%
price=pd.Series([10000,9000,8000])

# %%
price
# Out:
# 0    10000
# 1     9000
# 2     8000
# dtype: int64

# %%
df=pd.DataFrame({'메뉴':['비빔밥','김치찌개','된장찌개'],
                 '가격':[10000,9000,8000],
                 '원산지':['국내산','국내산','국내산']})

# %%
df
# Out:
#      메뉴     가격  원산지
# 0   비빔밥  10000  국내산
# 1  김치찌개   9000  국내산
# 2  된장찌개   8000  국내산

# %%
df['메뉴']
# Out:
# 0     비빔밥
# 1    김치찌개
# 2    된장찌개
# Name: 메뉴, dtype: object

# %%
df[['메뉴']]
# Out:
#      메뉴
# 0   비빔밥
# 1  김치찌개
# 2  된장찌개

# %%
df['메뉴']
# Out:
# 0     비빔밥
# 1    김치찌개
# 2    된장찌개
# Name: 메뉴, dtype: object

# %%
df[['메뉴','가격']]
# Out:
#      메뉴     가격
# 0   비빔밥  10000
# 1  김치찌개   9000
# 2  된장찌개   8000

# %%
cols=['메뉴','가격']

# %%
df[cols]
# Out:
#      메뉴     가격
# 0   비빔밥  10000
# 1  김치찌개   9000
# 2  된장찌개   8000

# %%
type[df]
# Out:
# type[     메뉴     가격  원산지
# 0   비빔밥  10000  국내산
# 1  김치찌개   9000  국내산
# 2  된장찌개   8000  국내산]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
print('df:',type(df))
# Out:
# df: <class 'pandas.core.frame.DataFrame'>

# %%
df=pd.DataFrame({
    '메뉴':['아메리카노','카페라떼','카페모카','카푸치노','에스프레소','밀크티','녹차'],
    '가격':[4500,5000,5500,5000,4000,5900,5300],
    '칼로리':[10,110,250,110,20,210,0]
})

# %%
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
df.to_csv('temp.csv')

# %%
temp_df=pd.read_csv('temp.csv')

# %%
temp_df.head()
# Out:
#    Unnamed: 0     메뉴    가격  칼로리
# 0           0  아메리카노  4500   10
# 1           1   카페라떼  5000  110
# 2           2   카페모카  5500  250
# 3           3   카푸치노  5000  110
# 4           4  에스프레소  4000   20

# %%
df.to_csv('cafe.csv',index=False)

# %%
df=pd.read_csv('cafe.csv')

# %%
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
df.shape
# Out:
# (7, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      int64
#  2   칼로리     7 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 300.0+ bytes

# %%
df.corr(numeric_only=True)
# Out:
#            가격       칼로리
# 가격   1.000000  0.713227
# 칼로리  0.713227  1.000000

# %%
df_car=pd.DataFrame({'car':['Sedan','SUV','Sedan','SUV','SUV','SUV','Sedan','Sedan','Sedan','Sedan','Sedan'],
                  'size':['S','M','S','S','M','M','L','S','S','M','S']})

# %%
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
df_car
# Out:
#       car size
# 0   Sedan    S
# 1     SUV    M
# 2   Sedan    S
# 3     SUV    S
# 4     SUV    M
# 5     SUV    M
# 6   Sedan    L
# 7   Sedan    S
# 8   Sedan    S
# 9   Sedan    M
# 10  Sedan    S

# %%
df_car.head(3)
# Out:
#      car size
# 0  Sedan    S
# 1    SUV    M
# 2  Sedan    S

# %%
df_car.nunique()
# Out:
# car     2
# size    3
# dtype: int64

# %%
print(df_car['car'].unique())
# Out:
# ['Sedan' 'SUV']

# %%
print(df_car['size'].unique())
# Out:
# ['S' 'M' 'L']

# %%
df_car['car'].value_counts()
# Out:
# car
# Sedan    7
# SUV      4
# Name: count, dtype: int64

# %%
df.value_counts()
# Out:
# 메뉴     가격    칼로리
# 녹차     5300  0      1
# 밀크티    5900  210    1
# 아메리카노  4500  10     1
# 에스프레소  4000  20     1
# 카페라떼   5000  110    1
# 카페모카   5500  250    1
# 카푸치노   5000  110    1
# Name: count, dtype: int64

# %%
df_car.describe()
# Out:
#           car size
# count      11   11
# unique      2    3
# top     Sedan    S
# freq        7    6

# %%
df.describe()
# Out:
#                 가격         칼로리
# count     7.000000    7.000000
# mean   5028.571429  101.428571
# std     631.702160   99.402980
# min    4000.000000    0.000000
# 25%    4750.000000   15.000000
# 50%    5000.000000  110.000000
# 75%    5400.000000  160.000000
# max    5900.000000  250.000000

# %%
df_car.describe()
# Out:
#           car size
# count      11   11
# unique      2    3
# top     Sedan    S
# freq        7    6

# %%
data={
    '메뉴':['아메리카노','카페라떼','카페모카','카푸치노','에스프레소','밀크티','녹차'],
    '가격':[4500,5000,5500,5000,4000,5900,5300],
    '칼로리':['10','110','250','110','20','210','0']
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
data
# Out:
# {'메뉴': ['아메리카노', '카페라떼', '카페모카', '카푸치노', '에스프레소', '밀크티', '녹차'],
#  '가격': [4500, 5000, 5500, 5000, 4000, 5900, 5300],
#  '칼로리': ['10', '110', '250', '110', '20', '210', '0']}

# %%
df['가격']=df['가격'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      int64
#  2   칼로리     7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 300.0+ bytes

# %%
df['칼로리']=df['칼로리'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      int64
#  2   칼로리     7 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 300.0+ bytes

# %%
df=pd.read_csv('cafe.csv')

# %%
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
df['new']=0

# %%
df.head()
# Out:
#       메뉴    가격  칼로리  new
# 0  아메리카노  4500   10    0
# 1   카페라떼  5000  110    0
# 2   카페모카  5500  250    0
# 3   카푸치노  5000  110    0
# 4  에스프레소  4000   20    0

# %%
discount=0.2

# %%
df['할인가']=df['가격']*(1-discount)

# %%
df
# Out:
#       메뉴    가격  칼로리  new     할인가
# 0  아메리카노  4500   10    0  3600.0
# 1   카페라떼  5000  110    0  4000.0
# 2   카페모카  5500  250    0  4400.0
# 3   카푸치노  5000  110    0  4000.0
# 4  에스프레소  4000   20    0  3200.0
# 5    밀크티  5900  210    0  4720.0
# 6     녹차  5300    0    0  4240.0

# %%
df=pd.read_csv('cafe.csv')

# %%
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
df.drop(1,axis=0,inplace=True)

# %%
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
df=df.drop('메뉴',axis=1)

# %%
df
# Out:
#      가격  칼로리
# 0  4500   10
# 2  5500  250
# 3  5000  110
# 4  4000   20
# 5  5900  210
# 6  5300    0

# %%
df=pd.read_csv('cafe.csv')

# %%
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
df.loc[0]
# Out:
# 메뉴     아메리카노
# 가격      4500
# 칼로리       10
# Name: 0, dtype: object

# %%
df.loc[1,'가격']
# Out:
# np.int64(5000)

# %%
df.loc[:,'가격']
# Out:
# 0    4500
# 1    5000
# 2    5500
# 3    5000
# 4    4000
# 5    5900
# 6    5300
# Name: 가격, dtype: int64

# %%
df.loc[2,'메뉴':'칼로리']
# Out:
# 메뉴     카페모카
# 가격     5500
# 칼로리     250
# Name: 2, dtype: object

# %%
df.loc[2,['메뉴','칼로리']]
# Out:
# 메뉴     카페모카
# 칼로리     250
# Name: 2, dtype: object

# %%
df.loc[1:3,['메뉴','칼로리']]
# Out:
#      메뉴  칼로리
# 1  카페라떼  110
# 2  카페모카  250
# 3  카푸치노  110

# %%
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
df.head()
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20

# %%
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
df.to_csv('cafe.csv')

# %%
df=pd.read_csv('cafe.csv')

# %%
df
# Out:
#    Unnamed: 0     메뉴    가격  칼로리
# 0           0  아메리카노  4500   10
# 1           1   카페라떼  5000  110
# 2           2   카페모카  5500  250
# 3           3   카푸치노  5000  110
# 4           4  에스프레소  4000   20
# 5           5    밀크티  5900  210
# 6           6     녹차  5300    0

# %%
df.head(2)
# Out:
#    Unnamed: 0     메뉴    가격  칼로리
# 0           0  아메리카노  4500   10
# 1           1   카페라떼  5000  110

# %%
df.loc[0]
# Out:
# Unnamed: 0        0
# 메뉴            아메리카노
# 가격             4500
# 칼로리              10
# Name: 0, dtype: object

# %%
df.loc[1]
# Out:
# Unnamed: 0       1
# 메뉴            카페라떼
# 가격            5000
# 칼로리            110
# Name: 1, dtype: object

# %%
df.loc[0,'가격']
# Out:
# np.int64(4500)

# %%
df.loc[:,'가격']
# Out:
# 0    4500
# 1    5000
# 2    5500
# 3    5000
# 4    4000
# 5    5900
# 6    5300
# Name: 가격, dtype: int64

# %%
df.loc[0:,'가격']
# Out:
# 0    4500
# 1    5000
# 2    5500
# 3    5000
# 4    4000
# 5    5900
# 6    5300
# Name: 가격, dtype: int64

# %%
df.loc[1:,'가격']
# Out:
# 1    5000
# 2    5500
# 3    5000
# 4    4000
# 5    5900
# 6    5300
# Name: 가격, dtype: int64

# %%
 df.loc[2,'메뉴':'칼로리']
# Out:
# 메뉴     카페모카
# 가격     5500
# 칼로리     250
# Name: 2, dtype: object

# %%
df.loc[2,['메뉴','칼로리']]
# Out:
# 메뉴     카페모카
# 칼로리     250
# Name: 2, dtype: object

# %%
df
# Out:
#    Unnamed: 0     메뉴    가격  칼로리
# 0           0  아메리카노  4500   10
# 1           1   카페라떼  5000  110
# 2           2   카페모카  5500  250
# 3           3   카푸치노  5000  110
# 4           4  에스프레소  4000   20
# 5           5    밀크티  5900  210
# 6           6     녹차  5300    0

# %%
df.drop(0,axis=0,inplace=True)

# %%
df
# Out:
#    Unnamed: 0     메뉴    가격  칼로리
# 1           1   카페라떼  5000  110
# 2           2   카페모카  5500  250
# 3           3   카푸치노  5000  110
# 4           4  에스프레소  4000   20
# 5           5    밀크티  5900  210
# 6           6     녹차  5300    0

# %%
df.iloc[0]
# Out:
# Unnamed: 0       1
# 메뉴            카페라떼
# 가격            5000
# 칼로리            110
# Name: 1, dtype: object

# %%
df.iloc[1:3]
# Out:
#    Unnamed: 0    메뉴    가격  칼로리
# 2           2  카페모카  5500  250
# 3           3  카푸치노  5000  110

# %%
df.head()
# Out:
#    Unnamed: 0     메뉴    가격  칼로리
# 1           1   카페라떼  5000  110
# 2           2   카페모카  5500  250
# 3           3   카푸치노  5000  110
# 4           4  에스프레소  4000   20
# 5           5    밀크티  5900  210

# %%
df.iloc[1:4]
# Out:
#    Unnamed: 0     메뉴    가격  칼로리
# 2           2   카페모카  5500  250
# 3           3   카푸치노  5000  110
# 4           4  에스프레소  4000   20

# %%
df.loc[2:4,'메뉴':'칼로리']
# Out:
#       메뉴    가격  칼로리
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20

# %%
df.head(2)
# Out:
#    Unnamed: 0    메뉴    가격  칼로리
# 1           1  카페라떼  5000  110
# 2           2  카페모카  5500  250

# %%
import numpy as np

# %%
df['원산지']=np.nan

# %%
df
# Out:
#    Unnamed: 0     메뉴    가격  칼로리  원산지
# 1           1   카페라떼  5000  110  NaN
# 2           2   카페모카  5500  250  NaN
# 3           3   카푸치노  5000  110  NaN
# 4           4  에스프레소  4000   20  NaN
# 5           5    밀크티  5900  210  NaN
# 6           6     녹차  5300    0  NaN

# %%
df
# Out:
#    Unnamed: 0     메뉴    가격  칼로리  원산지
# 1           1   카페라떼  5000  110  NaN
# 2           2   카페모카  5500  250  NaN
# 3           3   카푸치노  5000  110  NaN
# 4           4  에스프레소  4000   20  NaN
# 5           5    밀크티  5900  210  NaN
# 6           6     녹차  5300    0  NaN

# %%
df.loc[1,'원산지']='콜롬비아'
# Out:
# /tmp/ipykernel_11500/3595826506.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '콜롬비아' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[1,'원산지']='콜롬비아'

# %%
df
# Out:
#    Unnamed: 0     메뉴    가격  칼로리   원산지
# 1           1   카페라떼  5000  110  콜롬비아
# 2           2   카페모카  5500  250   NaN
# 3           3   카푸치노  5000  110   NaN
# 4           4  에스프레소  4000   20   NaN
# 5           5    밀크티  5900  210   NaN
# 6           6     녹차  5300    0   NaN

# %%
df.loc[2:6,'원산지']='과테말라'

# %%
df
# Out:
#    Unnamed: 0     메뉴    가격  칼로리   원산지
# 1           1   카페라떼  5000  110  콜롬비아
# 2           2   카페모카  5500  250  과테말라
# 3           3   카푸치노  5000  110  과테말라
# 4           4  에스프레소  4000   20  과테말라
# 5           5    밀크티  5900  210  과테말라
# 6           6     녹차  5300    0  과테말라

# %%
df.loc['시즌']=['크리스마스라떼',1,6000,300,'한국']

# %%
df
# Out:
#    Unnamed: 0     메뉴    가격  칼로리   원산지
# 1           1   카페라떼  5000  110  콜롬비아
# 2           2   카페모카  5500  250  과테말라
# 3           3   카푸치노  5000  110  과테말라
# 4           4  에스프레소  4000   20  과테말라
# 5           5    밀크티  5900  210  과테말라
# 6           6     녹차  5300    0  과테말라
# 시즌    크리스마스라떼      1  6000  300    한국

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df
# Out:
#        메뉴    가격  칼로리   원산지
# 1    카페라떼  5000  110  콜롬비아
# 2    카페모카  5500  250  과테말라
# 3    카푸치노  5000  110  과테말라
# 4   에스프레소  4000   20  과테말라
# 5     밀크티  5900  210  과테말라
# 6      녹차  5300    0  과테말라
# 시즌      1  6000  300    한국

# %%
df.loc[7]={'메뉴':'딴짓커피','가격':'3000','칼로리':'1100'}

# %%
df
# Out:
#        메뉴    가격   칼로리   원산지
# 1    카페라떼  5000   110  콜롬비아
# 2    카페모카  5500   250  과테말라
# 3    카푸치노  5000   110  과테말라
# 4   에스프레소  4000    20  과테말라
# 5     밀크티  5900   210  과테말라
# 6      녹차  5300     0  과테말라
# 시즌      1  6000   300    한국
# 7    딴짓커피  3000  1100   NaN

# %%
df.drop('시즌',axis=0,inplace=True)

# %%
df
# Out:
#       메뉴    가격   칼로리   원산지
# 1   카페라떼  5000   110  콜롬비아
# 2   카페모카  5500   250  과테말라
# 3   카푸치노  5000   110  과테말라
# 4  에스프레소  4000    20  과테말라
# 5    밀크티  5900   210  과테말라
# 6     녹차  5300     0  과테말라
# 7   딴짓커피  3000  1100   NaN

# %%
df.to_csv('cafe2.csv',index=False)

# %%
df=pd.read_csv('cafe2.csv')

# %%
df
# Out:
#       메뉴    가격   칼로리   원산지
# 0   카페라떼  5000   110  콜롬비아
# 1   카페모카  5500   250  과테말라
# 2   카푸치노  5000   110  과테말라
# 3  에스프레소  4000    20  과테말라
# 4    밀크티  5900   210  과테말라
# 5     녹차  5300     0  과테말라
# 6   딴짓커피  3000  1100   NaN

# %%
df.sort_index(ascending=False)
# Out:
#       메뉴    가격   칼로리   원산지
# 6   딴짓커피  3000  1100   NaN
# 5     녹차  5300     0  과테말라
# 4    밀크티  5900   210  과테말라
# 3  에스프레소  4000    20  과테말라
# 2   카푸치노  5000   110  과테말라
# 1   카페모카  5500   250  과테말라
# 0   카페라떼  5000   110  콜롬비아

# %%
df.sort_values('가격',ascending=False)
# Out:
#       메뉴    가격   칼로리   원산지
# 4    밀크티  5900   210  과테말라
# 1   카페모카  5500   250  과테말라
# 5     녹차  5300     0  과테말라
# 2   카푸치노  5000   110  과테말라
# 0   카페라떼  5000   110  콜롬비아
# 3  에스프레소  4000    20  과테말라
# 6   딴짓커피  3000  1100   NaN

# %%
df.sort_values(['가격','메뉴'],ascending=[False,True],inplace=True)

# %%
df
# Out:
#       메뉴    가격   칼로리   원산지
# 4    밀크티  5900   210  과테말라
# 1   카페모카  5500   250  과테말라
# 5     녹차  5300     0  과테말라
# 0   카페라떼  5000   110  콜롬비아
# 2   카푸치노  5000   110  과테말라
# 3  에스프레소  4000    20  과테말라
# 6   딴짓커피  3000  1100   NaN

# %%
df.reset_index(drop=True)
# Out:
#       메뉴    가격   칼로리   원산지
# 0    밀크티  5900   210  과테말라
# 1   카페모카  5500   250  과테말라
# 2     녹차  5300     0  과테말라
# 3   카페라떼  5000   110  콜롬비아
# 4   카푸치노  5000   110  과테말라
# 5  에스프레소  4000    20  과테말라
# 6   딴짓커피  3000  1100   NaN

# %%
df=pd.read_csv('cafe2.csv')

# %%
df
# Out:
#       메뉴    가격   칼로리   원산지
# 0   카페라떼  5000   110  콜롬비아
# 1   카페모카  5500   250  과테말라
# 2   카푸치노  5000   110  과테말라
# 3  에스프레소  4000    20  과테말라
# 4    밀크티  5900   210  과테말라
# 5     녹차  5300     0  과테말라
# 6   딴짓커피  3000  1100   NaN

# %%
df['칼로리']<50
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# Name: 칼로리, dtype: bool

# %%
cond=df['칼로리']<50

# %%
df[cond]
# Out:
#       메뉴    가격  칼로리   원산지
# 3  에스프레소  4000   20  과테말라
# 5     녹차  5300    0  과테말라

# %%
df[~cond]
# Out:
#      메뉴    가격   칼로리   원산지
# 0  카페라떼  5000   110  콜롬비아
# 1  카페모카  5500   250  과테말라
# 2  카푸치노  5000   110  과테말라
# 4   밀크티  5900   210  과테말라
# 6  딴짓커피  3000  1100   NaN

# %%
cond1=df['가격']>=5000
cond2=df['칼로리']>100
df[cond1&cond2]
# Out:
#      메뉴    가격  칼로리   원산지
# 0  카페라떼  5000  110  콜롬비아
# 1  카페모카  5500  250  과테말라
# 2  카푸치노  5000  110  과테말라
# 4   밀크티  5900  210  과테말라

# %%
cond1=df['가격']>=5000
cond2=df['칼로리']>100
df[cond1|cond2]
# Out:
#      메뉴    가격   칼로리   원산지
# 0  카페라떼  5000   110  콜롬비아
# 1  카페모카  5500   250  과테말라
# 2  카푸치노  5000   110  과테말라
# 4   밀크티  5900   210  과테말라
# 5    녹차  5300     0  과테말라
# 6  딴짓커피  3000  1100   NaN

# %%
cond=df['원산지']=='과테말라'

# %%
df[cond]
# Out:
#       메뉴    가격  칼로리   원산지
# 1   카페모카  5500  250  과테말라
# 2   카푸치노  5000  110  과테말라
# 3  에스프레소  4000   20  과테말라
# 4    밀크티  5900  210  과테말라
# 5     녹차  5300    0  과테말라

# %%
cond2=df['가격']<=5000

# %%
df[cond&cond2]
# Out:
#       메뉴    가격  칼로리   원산지
# 2   카푸치노  5000  110  과테말라
# 3  에스프레소  4000   20  과테말라

# %%
cond=df['메뉴'].isin(['녹차'])

# %%
df[cond]
# Out:
#    메뉴    가격  칼로리   원산지
# 5  녹차  5300    0  과테말라

# %%
box=['녹차','카푸치노','카페라떼']

# %%
cond=df.isin(box)

# %%
df[cond]
# Out:
#      메뉴  가격  칼로리  원산지
# 0  카페라떼 NaN  NaN  NaN
# 1   NaN NaN  NaN  NaN
# 2  카푸치노 NaN  NaN  NaN
# 3   NaN NaN  NaN  NaN
# 4   NaN NaN  NaN  NaN
# 5    녹차 NaN  NaN  NaN
# 6   NaN NaN  NaN  NaN

# %%
df=pd.read_csv('cafe2.csv')

# %%
df
# Out:
#       메뉴    가격   칼로리   원산지
# 0   카페라떼  5000   110  콜롬비아
# 1   카페모카  5500   250  과테말라
# 2   카푸치노  5000   110  과테말라
# 3  에스프레소  4000    20  과테말라
# 4    밀크티  5900   210  과테말라
# 5     녹차  5300     0  과테말라
# 6   딴짓커피  3000  1100   NaN

# %%
df.isnull()
# Out:
#       메뉴     가격    칼로리    원산지
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False  False  False
# 4  False  False  False  False
# 5  False  False  False  False
# 6  False  False  False   True

# %%
df.isnull()
# Out:
#       메뉴     가격    칼로리    원산지
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False  False  False
# 4  False  False  False  False
# 5  False  False  False  False
# 6  False  False  False   True

# %%
df.isnull().sum()
# Out:
# 메뉴     0
# 가격     0
# 칼로리    0
# 원산지    1
# dtype: int64

# %%
df.isna().sum()
# Out:
# 메뉴     0
# 가격     0
# 칼로리    0
# 원산지    1
# dtype: int64

# %%
df
# Out:
#       메뉴    가격   칼로리   원산지
# 0   카페라떼  5000   110  콜롬비아
# 1   카페모카  5500   250  과테말라
# 2   카푸치노  5000   110  과테말라
# 3  에스프레소  4000    20  과테말라
# 4    밀크티  5900   210  과테말라
# 5     녹차  5300     0  과테말라
# 6   딴짓커피  3000  1100   NaN

# %%
df['원산지'].fillna('코스타리카',inplace=True)
# Out:
# /tmp/ipykernel_11500/3660102855.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['원산지'].fillna('코스타리카',inplace=True)

# %%
df
# Out:
#       메뉴    가격   칼로리    원산지
# 0   카페라떼  5000   110   콜롬비아
# 1   카페모카  5500   250   과테말라
# 2   카푸치노  5000   110   과테말라
# 3  에스프레소  4000    20   과테말라
# 4    밀크티  5900   210   과테말라
# 5     녹차  5300     0   과테말라
# 6   딴짓커피  3000  1100  코스타리카

# %%
df.to_csv('cafe3.csv',index=False)

# %%
df
# Out:
#       메뉴    가격   칼로리    원산지
# 0   카페라떼  5000   110   콜롬비아
# 1   카페모카  5500   250   과테말라
# 2   카푸치노  5000   110   과테말라
# 3  에스프레소  4000    20   과테말라
# 4    밀크티  5900   210   과테말라
# 5     녹차  5300     0   과테말라
# 6   딴짓커피  3000  1100  코스타리카

# %%
df=pd.read_csv('cafe3.csv')

# %%
df
# Out:
#       메뉴    가격   칼로리    원산지
# 0   카페라떼  5000   110   콜롬비아
# 1   카페모카  5500   250   과테말라
# 2   카푸치노  5000   110   과테말라
# 3  에스프레소  4000    20   과테말라
# 4    밀크티  5900   210   과테말라
# 5     녹차  5300     0   과테말라
# 6   딴짓커피  3000  1100  코스타리카

# %%
df.replace('아메리카노','룽고',inplace=True)

# %%
df
# Out:
#       메뉴    가격   칼로리    원산지
# 0   카페라떼  5000   110   콜롬비아
# 1   카페모카  5500   250   과테말라
# 2   카푸치노  5000   110   과테말라
# 3  에스프레소  4000    20   과테말라
# 4    밀크티  5900   210   과테말라
# 5     녹차  5300     0   과테말라
# 6   딴짓커피  3000  1100  코스타리카

# %%
df.replace('녹차','그린티',inplace=True)

# %%
df
# Out:
#       메뉴    가격   칼로리    원산지
# 0   카페라떼  5000   110   콜롬비아
# 1   카페모카  5500   250   과테말라
# 2   카푸치노  5000   110   과테말라
# 3  에스프레소  4000    20   과테말라
# 4    밀크티  5900   210   과테말라
# 5    그린티  5300     0   과테말라
# 6   딴짓커피  3000  1100  코스타리카

# %%
change={'카페모카':'아메리카노','그린티':'녹차'}

# %%
df.replace(change,inplace=True)

# %%
df
# Out:
#       메뉴    가격   칼로리    원산지
# 0   카페라떼  5000   110   콜롬비아
# 1  아메리카노  5500   250   과테말라
# 2   카푸치노  5000   110   과테말라
# 3  에스프레소  4000    20   과테말라
# 4    밀크티  5900   210   과테말라
# 5     녹차  5300     0   과테말라
# 6   딴짓커피  3000  1100  코스타리카

# %%
df.loc[5,'원산지']='대한민국'

# %%
df
# Out:
#       메뉴    가격   칼로리    원산지
# 0   카페라떼  5000   110   콜롬비아
# 1  아메리카노  5500   250   과테말라
# 2   카푸치노  5000   110   과테말라
# 3  에스프레소  4000    20   과테말라
# 4    밀크티  5900   210   과테말라
# 5     녹차  5300     0   대한민국
# 6   딴짓커피  3000  1100  코스타리카

# %%
df.loc[1:2,'이벤트가']=1000

# %%
df
# Out:
#       메뉴    가격   칼로리    원산지    이벤트가
# 0   카페라떼  5000   110   콜롬비아     NaN
# 1  아메리카노  5500   250   과테말라  1000.0
# 2   카푸치노  5000   110   과테말라  1000.0
# 3  에스프레소  4000    20   과테말라     NaN
# 4    밀크티  5900   210   과테말라     NaN
# 5     녹차  5300     0   대한민국     NaN
# 6   딴짓커피  3000  1100  코스타리카     NaN

# %%
df.to_csv('cafe4.csv')

# %%
import pandas as pd

# %%
df=pd.DataFrame({'A':['데이터 분석','기본 학습서','퇴근 후 열공'],
                 'B':[10,20,30],
                 'C':['ab cd','AB CD','ab cd ']})

# %%
df
# Out:
#          A   B       C
# 0   데이터 분석  10   ab cd
# 1   기본 학습서  20   AB CD
# 2  퇴근 후 열공  30  ab cd

# %%
df.replace('분석','시각화')
# Out:
#          A   B       C
# 0   데이터 분석  10   ab cd
# 1   기본 학습서  20   AB CD
# 2  퇴근 후 열공  30  ab cd

# %%
df['A']=df['A'].str.replace('분석','시각화')

# %%
df
# Out:
#          A   B       C
# 0  데이터 시각화  10   ab cd
# 1   기본 학습서  20   AB CD
# 2  퇴근 후 열공  30  ab cd

# %%
df['B']=df['B'].replace(10,100)

# %%
df
# Out:
#          A    B       C
# 0  데이터 시각화  100   ab cd
# 1   기본 학습서   20   AB CD
# 2  퇴근 후 열공   30  ab cd

# %%
df['A'].str.split()
# Out:
# 0     [데이터, 시각화]
# 1      [기본, 학습서]
# 2    [퇴근, 후, 열공]
# Name: A, dtype: object

# %%
df['A'].str.split()[2]
# Out:
# ['퇴근', '후', '열공']

# %%
df['D']=df['A'].str.split().str[0]

# %%
df
# Out:
#          A    B       C    D
# 0  데이터 시각화  100   ab cd  데이터
# 1   기본 학습서   20   AB CD   기본
# 2  퇴근 후 열공   30  ab cd    퇴근

# %%
df['A'].str.contains('기본')
# Out:
# 0    False
# 1     True
# 2    False
# Name: A, dtype: bool

# %%
df['기본포함여부']=df['A'].str.contains('기본')

# %%
df
# Out:
#          A    B       C    D  기본포함여부
# 0  데이터 시각화  100   ab cd  데이터   False
# 1   기본 학습서   20   AB CD   기본    True
# 2  퇴근 후 열공   30  ab cd    퇴근   False

# %%
df
# Out:
#          A    B       C    D  기본포함여부
# 0  데이터 시각화  100   ab cd  데이터   False
# 1   기본 학습서   20   AB CD   기본    True
# 2  퇴근 후 열공   30  ab cd    퇴근   False

# %%
df['문자길이']=df['A'].str.len()

# %%
df
# Out:
#          A    B       C    D  기본포함여부  문자길이
# 0  데이터 시각화  100   ab cd  데이터   False     7
# 1   기본 학습서   20   AB CD   기본    True     6
# 2  퇴근 후 열공   30  ab cd    퇴근   False     7

# %%
'AB cd'=='ab CD'
# Out:
# False

# %%
df
# Out:
#          A    B       C    D  기본포함여부  문자길이
# 0  데이터 시각화  100   ab cd  데이터   False     7
# 1   기본 학습서   20   AB CD   기본    True     6
# 2  퇴근 후 열공   30  ab cd    퇴근   False     7

# %%
df['C']=df['C'].str.lower()

# %%
df
# Out:
#          A    B       C    D  기본포함여부  문자길이
# 0  데이터 시각화  100   ab cd  데이터   False     7
# 1   기본 학습서   20   ab cd   기본    True     6
# 2  퇴근 후 열공   30  ab cd    퇴근   False     7

# %%
df['C']=df['C'].str.upper()

# %%
df
# Out:
#          A    B       C    D  기본포함여부  문자길이
# 0  데이터 시각화  100   AB CD  데이터   False     7
# 1   기본 학습서   20   AB CD   기본    True     6
# 2  퇴근 후 열공   30  AB CD    퇴근   False     7

# %%
df['C']=='AB CD'
# Out:
# 0     True
# 1     True
# 2    False
# Name: C, dtype: bool

# %%
df['C']=df['C'].str.lower()
df['C']=df['C'].str.replace(" ","")

# %%
df
# Out:
#          A    B     C    D  기본포함여부  문자길이
# 0  데이터 시각화  100  abcd  데이터   False     7
# 1   기본 학습서   20  abcd   기본    True     6
# 2  퇴근 후 열공   30  abcd   퇴근   False     7

# %%
df['C'].str[1:3]
# Out:
# 0    bc
# 1    bc
# 2    bc
# Name: C, dtype: object

# %%
df['C'].str[2:3]
# Out:
# 0    c
# 1    c
# 2    c
# Name: C, dtype: object

# %%
df['C'][1:2]
# Out:
# 1    abcd
# Name: C, dtype: object

# %%
import pandas as pd
df=pd.read_csv('cafe4.csv')

# %%
df
# Out:
#    Unnamed: 0     메뉴    가격   칼로리    원산지    이벤트가
# 0           0   카페라떼  5000   110   콜롬비아     NaN
# 1           1  아메리카노  5500   250   과테말라  1000.0
# 2           2   카푸치노  5000   110   과테말라  1000.0
# 3           3  에스프레소  4000    20   과테말라     NaN
# 4           4    밀크티  5900   210   과테말라     NaN
# 5           5     녹차  5300     0   대한민국     NaN
# 6           6   딴짓커피  3000  1100  코스타리카     NaN

# %%
df['메뉴'].str.len()
# Out:
# 0    4
# 1    5
# 2    4
# 3    5
# 4    3
# 5    2
# 6    4
# Name: 메뉴, dtype: int64

# %%
print(len(df))
# Out:
# 7

# %%
df.shape
# Out:
# (7, 6)

# %%
cond=df['가격']>5000

# %%
cond
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5     True
# 6    False
# Name: 가격, dtype: bool

# %%
sum(cond)
# Out:
# 3

# %%
len(df[cond])
# Out:
# 3

# %%
df.sum(numeric_only=True)
# Out:
# Unnamed: 0       21.0
# 가격            33700.0
# 칼로리            1800.0
# 이벤트가           2000.0
# dtype: float64

# %%
df
# Out:
#    Unnamed: 0     메뉴    가격   칼로리    원산지    이벤트가
# 0           0   카페라떼  5000   110   콜롬비아     NaN
# 1           1  아메리카노  5500   250   과테말라  1000.0
# 2           2   카푸치노  5000   110   과테말라  1000.0
# 3           3  에스프레소  4000    20   과테말라     NaN
# 4           4    밀크티  5900   210   과테말라     NaN
# 5           5     녹차  5300     0   대한민국     NaN
# 6           6   딴짓커피  3000  1100  코스타리카     NaN

# %%
df=df.T

# %%
df
# Out:
#                0       1       2      3     4     5      6
# Unnamed: 0     0       1       2      3     4     5      6
# 메뉴          카페라떼   아메리카노    카푸치노  에스프레소   밀크티    녹차   딴짓커피
# 가격          5000    5500    5000   4000  5900  5300   3000
# 칼로리          110     250     110     20   210     0   1100
# 원산지         콜롬비아    과테말라    과테말라   과테말라  과테말라  대한민국  코스타리카
# 이벤트가         NaN  1000.0  1000.0    NaN   NaN   NaN    NaN

# %%
df.sum(axis=1,numeric_only=True)
# Out:
# Unnamed: 0    0.0
# 메뉴            0.0
# 가격            0.0
# 칼로리           0.0
# 원산지           0.0
# 이벤트가          0.0
# dtype: float64

# %%
df=pd.read_csv('cafe4.csv')

# %%
df
# Out:
#    Unnamed: 0     메뉴    가격   칼로리    원산지    이벤트가
# 0           0   카페라떼  5000   110   콜롬비아     NaN
# 1           1  아메리카노  5500   250   과테말라  1000.0
# 2           2   카푸치노  5000   110   과테말라  1000.0
# 3           3  에스프레소  4000    20   과테말라     NaN
# 4           4    밀크티  5900   210   과테말라     NaN
# 5           5     녹차  5300     0   대한민국     NaN
# 6           6   딴짓커피  3000  1100  코스타리카     NaN

# %%
df.sum(axis=1,numeric_only=True)
# Out:
# 0    5110.0
# 1    6751.0
# 2    6112.0
# 3    4023.0
# 4    6114.0
# 5    5305.0
# 6    4106.0
# dtype: float64

# %%
df
# Out:
#    Unnamed: 0     메뉴    가격   칼로리    원산지    이벤트가
# 0           0   카페라떼  5000   110   콜롬비아     NaN
# 1           1  아메리카노  5500   250   과테말라  1000.0
# 2           2   카푸치노  5000   110   과테말라  1000.0
# 3           3  에스프레소  4000    20   과테말라     NaN
# 4           4    밀크티  5900   210   과테말라     NaN
# 5           5     녹차  5300     0   대한민국     NaN
# 6           6   딴짓커피  3000  1100  코스타리카     NaN

# %%
df=pd.read_csv('cafe4.csv')

# %%
df
# Out:
#    Unnamed: 0     메뉴    가격   칼로리    원산지    이벤트가
# 0           0   카페라떼  5000   110   콜롬비아     NaN
# 1           1  아메리카노  5500   250   과테말라  1000.0
# 2           2   카푸치노  5000   110   과테말라  1000.0
# 3           3  에스프레소  4000    20   과테말라     NaN
# 4           4    밀크티  5900   210   과테말라     NaN
# 5           5     녹차  5300     0   대한민국     NaN
# 6           6   딴짓커피  3000  1100  코스타리카     NaN

# %%
df.to_csv('cafe4.csv',index=None)

# %%
df=pd.read_csv('cafe4.csv',index_col=0)

# %%
df
# Out:
#                메뉴    가격   칼로리    원산지    이벤트가
# Unnamed: 0
# 0            카페라떼  5000   110   콜롬비아     NaN
# 1           아메리카노  5500   250   과테말라  1000.0
# 2            카푸치노  5000   110   과테말라  1000.0
# 3           에스프레소  4000    20   과테말라     NaN
# 4             밀크티  5900   210   과테말라     NaN
# 5              녹차  5300     0   대한민국     NaN
# 6            딴짓커피  3000  1100  코스타리카     NaN

# %%
cond=df['가격'].quantile(.25)>df['가격']

# %%
df[cond]
# Out:
#                메뉴    가격   칼로리    원산지  이벤트가
# Unnamed: 0
# 3           에스프레소  4000    20   과테말라   NaN
# 6            딴짓커피  3000  1100  코스타리카   NaN

# %%
cond=df['가격']>df['가격'].quantile(.75)

# %%
df[cond]
# Out:
#                메뉴    가격  칼로리   원산지    이벤트가
# Unnamed: 0
# 1           아메리카노  5500  250  과테말라  1000.0
# 4             밀크티  5900  210  과테말라     NaN

# %%
df['원산지'].mode()[0]
# Out:
# '과테말라'

# %%
df['가격'].idxmax()
# Out:
# np.int64(4)

# %%
df['가격'].idxmin()
# Out:
# np.int64(6)

# %%
max_ind=df['가격'].idxmax()

# %%
max_ind
# Out:
# np.int64(4)

# %%
df.loc[max_ind]['메뉴']
# Out:
# '밀크티'

# %%
df.nlargest(3,'가격')
# Out:
#                메뉴    가격  칼로리   원산지    이벤트가
# Unnamed: 0
# 4             밀크티  5900  210  과테말라     NaN
# 1           아메리카노  5500  250  과테말라  1000.0
# 5              녹차  5300    0  대한민국     NaN

# %%
df.nsmallest(3,'가격')
# Out:
#                메뉴    가격   칼로리    원산지  이벤트가
# Unnamed: 0
# 6            딴짓커피  3000  1100  코스타리카   NaN
# 3           에스프레소  4000    20   과테말라   NaN
# 0            카페라떼  5000   110   콜롬비아   NaN

# %%
df.sort_values('가격',ascending=False).head(3)
# Out:
#                메뉴    가격  칼로리   원산지    이벤트가
# Unnamed: 0
# 4             밀크티  5900  210  과테말라     NaN
# 1           아메리카노  5500  250  과테말라  1000.0
# 5              녹차  5300    0  대한민국     NaN

# %%
def cal(x):
  if x>=100:
    return "No"
  else:
    return "Yes"

# %%
df['먹어도 될까요']=df['칼로리'].apply(cal)

# %%
df
# Out:
#                메뉴    가격   칼로리    원산지    이벤트가 먹어도 될까요
# Unnamed: 0
# 0            카페라떼  5000   110   콜롬비아     NaN      No
# 1           아메리카노  5500   250   과테말라  1000.0      No
# 2            카푸치노  5000   110   과테말라  1000.0      No
# 3           에스프레소  4000    20   과테말라     NaN     Yes
# 4             밀크티  5900   210   과테말라     NaN      No
# 5              녹차  5300     0   대한민국     NaN     Yes
# 6            딴짓커피  3000  1100  코스타리카     NaN      No

# %%
import pandas as pd
df=pd.DataFrame({'Name':{0:'쿼카',1:'알파카',2:'시바견'},
                 '수학':{0:90,1:93,2:85},
                 '영어':{0:92,1:84,2:86},
                 '국어':{0:91,1:94,2:83}})

# %%
df
# Out:
#   Name  수학  영어  국어
# 0   쿼카  90  92  91
# 1  알파카  93  84  94
# 2  시바견  85  86  83

# %%
pd.melt(df,id_vars=['Name'])
# Out:
#   Name variable  value
# 0   쿼카       수학     90
# 1  알파카       수학     93
# 2  시바견       수학     85
# 3   쿼카       영어     92
# 4  알파카       영어     84
# 5  시바견       영어     86
# 6   쿼카       국어     91
# 7  알파카       국어     94
# 8  시바견       국어     83

# %%
pd.melt(df,id_vars=['Name'],value_vars=['수학','영어'],var_name='과목',value_name='점수')
# Out:
#   Name  과목  점수
# 0   쿼카  수학  90
# 1  알파카  수학  93
# 2  시바견  수학  85
# 3   쿼카  영어  92
# 4  알파카  영어  84
# 5  시바견  영어  86

# %%
import pandas as pd
df=pd.DataFrame({'반':{0:'A반',1:'B반',2:'C반'},
                '이름':{0:'쿼카',1:'알파카',2:'시바견'},
                 '수학':{0:90,1:93,2:85},
                 '영어':{0:92,1:84,2:86},
                 '국어':{0:91,1:94,2:83}})

# %%
df
# Out:
#     반   이름  수학  영어  국어
# 0  A반   쿼카  90  92  91
# 1  B반  알파카  93  84  94
# 2  C반  시바견  85  86  83

# %%
pd.melt(df,id_vars=['반','이름'],value_vars=['수학','영어'],var_name='과목',value_name='점수')
# Out:
#     반   이름  과목  점수
# 0  A반   쿼카  수학  90
# 1  B반  알파카  수학  93
# 2  C반  시바견  수학  85
# 3  A반   쿼카  영어  92
# 4  B반  알파카  영어  84
# 5  C반  시바견  영어  86

# %%
df=pd.read_csv('cafe4.csv',index_col=0)

# %%
df
# Out:
#                메뉴    가격   칼로리    원산지    이벤트가
# Unnamed: 0
# 0            카페라떼  5000   110   콜롬비아     NaN
# 1           아메리카노  5500   250   과테말라  1000.0
# 2            카푸치노  5000   110   과테말라  1000.0
# 3           에스프레소  4000    20   과테말라     NaN
# 4             밀크티  5900   210   과테말라     NaN
# 5              녹차  5300     0   대한민국     NaN
# 6            딴짓커피  3000  1100  코스타리카     NaN

# %%
df.groupby(['원산지','칼로리']).mean(numeric_only=True)
# Out:
#                 가격    이벤트가
# 원산지   칼로리
# 과테말라  20    4000.0     NaN
#       110   5000.0  1000.0
#       210   5900.0     NaN
#       250   5500.0  1000.0
# 대한민국  0     5300.0     NaN
# 코스타리카 1100  3000.0     NaN
# 콜롬비아  110   5000.0     NaN

# %%
import pandas as pd
import numpy as np

# %%
df.groupby(['원산지','칼로리'])[['가격', '이벤트가']].agg(['mean','sum'])
# Out:
#                 가격          이벤트가
#               mean   sum    mean     sum
# 원산지   칼로리
# 과테말라  20    4000.0  4000     NaN     0.0
#       110   5000.0  5000  1000.0  1000.0
#       210   5900.0  5900     NaN     0.0
#       250   5500.0  5500  1000.0  1000.0
# 대한민국  0     5300.0  5300     NaN     0.0
# 코스타리카 1100  3000.0  3000     NaN     0.0
# 콜롬비아  110   5000.0  5000     NaN     0.0

# %%
df.groupby(['원산지','칼로리'])[['가격','이벤트가']].agg(['mean','sum'])
# Out:
#                 가격          이벤트가
#               mean   sum    mean     sum
# 원산지   칼로리
# 과테말라  20    4000.0  4000     NaN     0.0
#       110   5000.0  5000  1000.0  1000.0
#       210   5900.0  5900     NaN     0.0
#       250   5500.0  5500  1000.0  1000.0
# 대한민국  0     5300.0  5300     NaN     0.0
# 코스타리카 1100  3000.0  3000     NaN     0.0
# 콜롬비아  110   5000.0  5000     NaN     0.0

# %%
df.groupby(['원산지','칼로리']).mean(numeric_only=True).reset_index()
# Out:
#      원산지   칼로리      가격    이벤트가
# 0   과테말라    20  4000.0     NaN
# 1   과테말라   110  5000.0  1000.0
# 2   과테말라   210  5900.0     NaN
# 3   과테말라   250  5500.0  1000.0
# 4   대한민국     0  5300.0     NaN
# 5  코스타리카  1100  3000.0     NaN
# 6   콜롬비아   110  5000.0     NaN

# %%
import pandas as pd

# %%
df=pd.DataFrame({'과일':['딸기','블루베리','딸기','블루베리','딸기','블루베리','딸기','블루베리'],
                 '가격':[1000,None,1500,None,2000,2500,None,1800]})

# %%
df
# Out:
#      과일      가격
# 0    딸기  1000.0
# 1  블루베리     NaN
# 2    딸기  1500.0
# 3  블루베리     NaN
# 4    딸기  2000.0
# 5  블루베리  2500.0
# 6    딸기     NaN
# 7  블루베리  1800.0

# %%
price=df.groupby('과일')['가격'].transform('mean')

# %%
price
# Out:
# 0    1500.0
# 1    2150.0
# 2    1500.0
# 3    2150.0
# 4    1500.0
# 5    2150.0
# 6    1500.0
# 7    2150.0
# Name: 가격, dtype: float64

# %%
df['가격']=df['가격'].fillna(price)

# %%
df
# Out:
#      과일      가격
# 0    딸기  1000.0
# 1  블루베리  2150.0
# 2    딸기  1500.0
# 3  블루베리  2150.0
# 4    딸기  2000.0
# 5  블루베리  2500.0
# 6    딸기  1500.0
# 7  블루베리  1800.0

# %%
df=pd.DataFrame({'과일':['딸기','블루베리','딸기','블루베리','딸기','블루베리','딸기','블루베리'],
                 '등급':['B','B','A','A','A','A','B','B'],
                 '가격':[1000,None,1500,None,2000,2500,None,1800],
                 })

# %%
df
# Out:
#      과일 등급      가격
# 0    딸기  B  1000.0
# 1  블루베리  B     NaN
# 2    딸기  A  1500.0
# 3  블루베리  A     NaN
# 4    딸기  A  2000.0
# 5  블루베리  A  2500.0
# 6    딸기  B     NaN
# 7  블루베리  B  1800.0

# %%
price=df.groupby(['과일','등급'])['가격'].transform('mean')

# %%
price
# Out:
# 0    1000.0
# 1    1800.0
# 2    1750.0
# 3    2500.0
# 4    1750.0
# 5    2500.0
# 6    1000.0
# 7    1800.0
# Name: 가격, dtype: float64

# %%
df['가격']=df['가격'].fillna(price)

# %%
df
# Out:
#      과일 등급      가격
# 0    딸기  B  1000.0
# 1  블루베리  B  1800.0
# 2    딸기  A  1500.0
# 3  블루베리  A  2500.0
# 4    딸기  A  2000.0
# 5  블루베리  A  2500.0
# 6    딸기  B  1000.0
# 7  블루베리  B  1800.0

# %%
import pandas as pd

# %%
df=pd.DataFrame({'커피종류':['아메리카노','아메리카노','아메리카노','라떼','라떼','라떼'],
                 '컵크기':['Small','Medium','Large','Small','Medium','Large'],
                 '판매량':[120,150,200,100,130,180]})

# %%
df
# Out:
#     커피종류     컵크기  판매량
# 0  아메리카노   Small  120
# 1  아메리카노  Medium  150
# 2  아메리카노   Large  200
# 3     라떼   Small  100
# 4     라떼  Medium  130
# 5     라떼   Large  180

# %%
grouped=df.groupby(['커피종류','컵크기'])['판매량'].sum()

# %%
grouped
# Out:
# 커피종류   컵크기
# 라떼     Large     180
#        Medium    130
#        Small     100
# 아메리카노  Large     200
#        Medium    150
#        Small     120
# Name: 판매량, dtype: int64

# %%
grouped.unstack().unstack()
# Out:
# 컵크기     커피종류
# Large   라떼       180
#         아메리카노    200
# Medium  라떼       130
#         아메리카노    150
# Small   라떼       100
#         아메리카노    120
# dtype: int64

# %%
import pandas as pd
data={'Data1':['2024-02-17','2024-02-18','2024-02-19','2024-02-20'],
      'Data2':['2024:02:17','2024:02:18','2024:02:19','2024:02:20'],
      'Data3':['24/02/17','24/02/18','24/02/19','24/02/20'],
      'Data4':['02/17/2024','02/18/2024','02/19/2024','02/20/2024'],
      'Data5':['17-Feb-2024','18-Feb-2024','19-Feb-2024','20-Feb-2024'],
      'DateTime1':['2024-02-17 13:50:30','2024-02-18 14:55:45','2024-02-19 03:30:15','2024-02-20 16:10:50'],
      'DataTime2':['2024-02-17','2024-02-18','2024-02-19','2024-02-20'],
      'DataTime3':['2024-02-17','2024-02-18','2024-02-19','2024-02-20'],
      'DataTime4':['2024-02-17','2024-02-18','2024-02-19','2024-02-20']}

# %%
data
# Out:
# {'Data1': ['2024-02-17', '2024-02-18', '2024-02-19', '2024-02-20'],
#  'Data2': ['2024:02:17', '2024:02:18', '2024:02:19', '2024:02:20'],
#  'Data3': ['24/02/17', '24/02/18', '24/02/19', '24/02/20'],
#  'Data4': ['02/17/2024', '02/18/2024', '02/19/2024', '02/20/2024'],
#  'Data5': ['17-Feb-2024', '18-Feb-2024', '19-Feb-2024', '20-Feb-2024'],
#  'DateTime1': ['2024-02-17 13:50:30',
#   '2024-02-18 14:55:45',
#   '2024-02-19 03:30:15',
#   '2024-02-20 16:10:50'],
#  'DataTime2': ['2024-02-17', '2024-02-18', '2024-02-19', '2024-02-20'],
#  'DataTime3': ['2024-02-17', '2024-02-18', '2024-02-19', '2024-02-20'],
#  'DataTime4': ['2024-02-17', '2024-02-18', '2024-02-19', '2024-02-20']}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#         Data1       Data2     Data3       Data4        Data5  \
# 0  2024-02-17  2024:02:17  24/02/17  02/17/2024  17-Feb-2024
# 1  2024-02-18  2024:02:18  24/02/18  02/18/2024  18-Feb-2024
# 2  2024-02-19  2024:02:19  24/02/19  02/19/2024  19-Feb-2024
# 3  2024-02-20  2024:02:20  24/02/20  02/20/2024  20-Feb-2024
#
#              DateTime1   DataTime2   DataTime3   DataTime4
# 0  2024-02-17 13:50:30  2024-02-17  2024-02-17  2024-02-17
# 1  2024-02-18 14:55:45  2024-02-18  2024-02-18  2024-02-18
# 2  2024-02-19 03:30:15  2024-02-19  2024-02-19  2024-02-19
# 3  2024-02-20 16:10:50  2024-02-20  2024-02-20  2024-02-20

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Data1      4 non-null      object
#  1   Data2      4 non-null      object
#  2   Data3      4 non-null      object
#  3   Data4      4 non-null      object
#  4   Data5      4 non-null      object
#  5   DateTime1  4 non-null      object
#  6   DataTime2  4 non-null      object
#  7   DataTime3  4 non-null      object
#  8   DataTime4  4 non-null      object
# dtypes: object(9)
# memory usage: 420.0+ bytes

# %%
df.to_csv('date_data.csv',index=False)

# %%
df
# Out:
#         Data1       Data2     Data3       Data4        Data5  \
# 0  2024-02-17  2024:02:17  24/02/17  02/17/2024  17-Feb-2024
# 1  2024-02-18  2024:02:18  24/02/18  02/18/2024  18-Feb-2024
# 2  2024-02-19  2024:02:19  24/02/19  02/19/2024  19-Feb-2024
# 3  2024-02-20  2024:02:20  24/02/20  02/20/2024  20-Feb-2024
#
#              DateTime1   DataTime2   DataTime3   DataTime4
# 0  2024-02-17 13:50:30  2024-02-17  2024-02-17  2024-02-17
# 1  2024-02-18 14:55:45  2024-02-18  2024-02-18  2024-02-18
# 2  2024-02-19 03:30:15  2024-02-19  2024-02-19  2024-02-19
# 3  2024-02-20 16:10:50  2024-02-20  2024-02-20  2024-02-20

# %%
df
# Out:
#         Data1       Data2     Data3       Data4        Data5  \
# 0  2024-02-17  2024:02:17  24/02/17  02/17/2024  17-Feb-2024
# 1  2024-02-18  2024:02:18  24/02/18  02/18/2024  18-Feb-2024
# 2  2024-02-19  2024:02:19  24/02/19  02/19/2024  19-Feb-2024
# 3  2024-02-20  2024:02:20  24/02/20  02/20/2024  20-Feb-2024
#
#              DateTime1   DataTime2   DataTime3   DataTime4
# 0  2024-02-17 13:50:30  2024-02-17  2024-02-17  2024-02-17
# 1  2024-02-18 14:55:45  2024-02-18  2024-02-18  2024-02-18
# 2  2024-02-19 03:30:15  2024-02-19  2024-02-19  2024-02-19
# 3  2024-02-20 16:10:50  2024-02-20  2024-02-20  2024-02-20

# %%
df=pd.read_csv('date_data.csv')

# %%
df
# Out:
#         Data1       Data2     Data3       Data4        Data5  \
# 0  2024-02-17  2024:02:17  24/02/17  02/17/2024  17-Feb-2024
# 1  2024-02-18  2024:02:18  24/02/18  02/18/2024  18-Feb-2024
# 2  2024-02-19  2024:02:19  24/02/19  02/19/2024  19-Feb-2024
# 3  2024-02-20  2024:02:20  24/02/20  02/20/2024  20-Feb-2024
#
#              DateTime1   DataTime2   DataTime3   DataTime4
# 0  2024-02-17 13:50:30  2024-02-17  2024-02-17  2024-02-17
# 1  2024-02-18 14:55:45  2024-02-18  2024-02-18  2024-02-18
# 2  2024-02-19 03:30:15  2024-02-19  2024-02-19  2024-02-19
# 3  2024-02-20 16:10:50  2024-02-20  2024-02-20  2024-02-20

# %%
df['Data1']=pd.to_datetime(df['Data1'])
df['Data2']=pd.to_datetime(df['Data2'],format='%Y:%m:%d')
df['Data3']=pd.to_datetime(df['Data3'])
df['Data3']=pd.to_datetime(df['Data3'])
df['Data4']=pd.to_datetime(df['Data4'])
df['Data5']=pd.to_datetime(df['Data5'])
df['DateTime1']=pd.to_datetime(df['DateTime1'])
df['DataTime2']=pd.to_datetime(df['DataTime2'])
df['DataTime3']=pd.to_datetime(df['DataTime3'])
df['DataTime4']=pd.to_datetime(df['DataTime4'])
# Out:
# /tmp/ipykernel_11500/873710502.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Data3']=pd.to_datetime(df['Data3'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Data1      4 non-null      datetime64[ns]
#  1   Data2      4 non-null      datetime64[ns]
#  2   Data3      4 non-null      datetime64[ns]
#  3   Data4      4 non-null      datetime64[ns]
#  4   Data5      4 non-null      datetime64[ns]
#  5   DateTime1  4 non-null      datetime64[ns]
#  6   DataTime2  4 non-null      datetime64[ns]
#  7   DataTime3  4 non-null      datetime64[ns]
#  8   DataTime4  4 non-null      datetime64[ns]
# dtypes: datetime64[ns](9)
# memory usage: 420.0 bytes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Data1      4 non-null      datetime64[ns]
#  1   Data2      4 non-null      datetime64[ns]
#  2   Data3      4 non-null      datetime64[ns]
#  3   Data4      4 non-null      datetime64[ns]
#  4   Data5      4 non-null      datetime64[ns]
#  5   DateTime1  4 non-null      datetime64[ns]
#  6   DataTime2  4 non-null      datetime64[ns]
#  7   DataTime3  4 non-null      datetime64[ns]
#  8   DataTime4  4 non-null      datetime64[ns]
# dtypes: datetime64[ns](9)
# memory usage: 420.0 bytes

# %%
df
# Out:
#        Data1      Data2      Data3      Data4      Data5           DateTime1  \
# 0 2024-02-17 2024-02-17 2017-02-24 2024-02-17 2024-02-17 2024-02-17 13:50:30
# 1 2024-02-18 2024-02-18 2018-02-24 2024-02-18 2024-02-18 2024-02-18 14:55:45
# 2 2024-02-19 2024-02-19 2019-02-24 2024-02-19 2024-02-19 2024-02-19 03:30:15
# 3 2024-02-20 2024-02-20 2020-02-24 2024-02-20 2024-02-20 2024-02-20 16:10:50
#
#    DataTime2  DataTime3  DataTime4
# 0 2024-02-17 2024-02-17 2024-02-17
# 1 2024-02-18 2024-02-18 2024-02-18
# 2 2024-02-19 2024-02-19 2024-02-19
# 3 2024-02-20 2024-02-20 2024-02-20

# %%
df=pd.read_csv('date_data.csv')

# %%
df
# Out:
#         Data1       Data2     Data3       Data4        Data5  \
# 0  2024-02-17  2024:02:17  24/02/17  02/17/2024  17-Feb-2024
# 1  2024-02-18  2024:02:18  24/02/18  02/18/2024  18-Feb-2024
# 2  2024-02-19  2024:02:19  24/02/19  02/19/2024  19-Feb-2024
# 3  2024-02-20  2024:02:20  24/02/20  02/20/2024  20-Feb-2024
#
#              DateTime1   DataTime2   DataTime3   DataTime4
# 0  2024-02-17 13:50:30  2024-02-17  2024-02-17  2024-02-17
# 1  2024-02-18 14:55:45  2024-02-18  2024-02-18  2024-02-18
# 2  2024-02-19 03:30:15  2024-02-19  2024-02-19  2024-02-19
# 3  2024-02-20 16:10:50  2024-02-20  2024-02-20  2024-02-20

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Data1      4 non-null      object
#  1   Data2      4 non-null      object
#  2   Data3      4 non-null      object
#  3   Data4      4 non-null      object
#  4   Data5      4 non-null      object
#  5   DateTime1  4 non-null      object
#  6   DataTime2  4 non-null      object
#  7   DataTime3  4 non-null      object
#  8   DataTime4  4 non-null      object
# dtypes: object(9)
# memory usage: 420.0+ bytes

# %%
df['Data1']=pd.to_datetime(df['Data1'])
df['Data2']=pd.to_datetime(df['Data2'],format='%Y:%m:%d')
df['Data3']=pd.to_datetime(df['Data3'])
df['Data4']=pd.to_datetime(df['Data4'])
df['Data5']=pd.to_datetime(df['Data5'])
df['DataTime1']=pd.to_datetime(df['DateTime1'],format='%Y-%m-%d %H:%M:%S')
df['DataTime2']=pd.to_datetime(df['DataTime2'])
df['DataTime3']=pd.to_datetime(df['DataTime3'])
df['DataTime4']=pd.to_datetime(df['DataTime4'])
# Out:
# /tmp/ipykernel_11500/1822885798.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Data3']=pd.to_datetime(df['Data3'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Data1      4 non-null      datetime64[ns]
#  1   Data2      4 non-null      datetime64[ns]
#  2   Data3      4 non-null      datetime64[ns]
#  3   Data4      4 non-null      datetime64[ns]
#  4   Data5      4 non-null      datetime64[ns]
#  5   DateTime1  4 non-null      object
#  6   DataTime2  4 non-null      datetime64[ns]
#  7   DataTime3  4 non-null      datetime64[ns]
#  8   DataTime4  4 non-null      datetime64[ns]
#  9   DataTime1  4 non-null      datetime64[ns]
# dtypes: datetime64[ns](9), object(1)
# memory usage: 452.0+ bytes

# %%
df
# Out:
#        Data1      Data2      Data3      Data4      Data5            DateTime1  \
# 0 2024-02-17 2024-02-17 2017-02-24 2024-02-17 2024-02-17  2024-02-17 13:50:30
# 1 2024-02-18 2024-02-18 2018-02-24 2024-02-18 2024-02-18  2024-02-18 14:55:45
# 2 2024-02-19 2024-02-19 2019-02-24 2024-02-19 2024-02-19  2024-02-19 03:30:15
# 3 2024-02-20 2024-02-20 2020-02-24 2024-02-20 2024-02-20  2024-02-20 16:10:50
#
#    DataTime2  DataTime3  DataTime4           DataTime1
# 0 2024-02-17 2024-02-17 2024-02-17 2024-02-17 13:50:30
# 1 2024-02-18 2024-02-18 2024-02-18 2024-02-18 14:55:45
# 2 2024-02-19 2024-02-19 2024-02-19 2024-02-19 03:30:15
# 3 2024-02-20 2024-02-20 2024-02-20 2024-02-20 16:10:50

# %%
df['year']=df['DataTime2'].dt.year
df['month']=df['DataTime2'].dt.month
df['day']=df['DataTime2'].dt.day

# %%
df
# Out:
#        Data1      Data2      Data3      Data4      Data5            DateTime1  \
# 0 2024-02-17 2024-02-17 2017-02-24 2024-02-17 2024-02-17  2024-02-17 13:50:30
# 1 2024-02-18 2024-02-18 2018-02-24 2024-02-18 2024-02-18  2024-02-18 14:55:45
# 2 2024-02-19 2024-02-19 2019-02-24 2024-02-19 2024-02-19  2024-02-19 03:30:15
# 3 2024-02-20 2024-02-20 2020-02-24 2024-02-20 2024-02-20  2024-02-20 16:10:50
#
#    DataTime2  DataTime3  DataTime4           DataTime1  year  month  day
# 0 2024-02-17 2024-02-17 2024-02-17 2024-02-17 13:50:30  2024      2   17
# 1 2024-02-18 2024-02-18 2024-02-18 2024-02-18 14:55:45  2024      2   18
# 2 2024-02-19 2024-02-19 2024-02-19 2024-02-19 03:30:15  2024      2   19
# 3 2024-02-20 2024-02-20 2024-02-20 2024-02-20 16:10:50  2024      2   20

# %%
df['DataTime2'].dt.dayofweek
# Out:
# 0    5
# 1    6
# 2    0
# 3    1
# Name: DataTime2, dtype: int32

# %%
df['DataTime2'].dt.to_period('Q')
# Out:
# 0    2024Q1
# 1    2024Q1
# 2    2024Q1
# 3    2024Q1
# Name: DataTime2, dtype: period[Q-DEC]

# %%
df=pd.read_csv('date_data.csv',usecols=['DataTime4'],parse_dates=['DataTime4'])

# %%
day=pd.Timedelta(days=99)
df['100day']=df['DataTime4']+day
df
# Out:
#    DataTime4     100day
# 0 2024-02-17 2024-05-26
# 1 2024-02-18 2024-05-27
# 2 2024-02-19 2024-05-28
# 3 2024-02-20 2024-05-29

# %%
hour=pd.Timedelta(hours=100)
df['100hours']=df['DataTime4']+hour
df
# Out:
#    DataTime4     100day            100hours
# 0 2024-02-17 2024-05-26 2024-02-21 04:00:00
# 1 2024-02-18 2024-05-27 2024-02-22 04:00:00
# 2 2024-02-19 2024-05-28 2024-02-23 04:00:00
# 3 2024-02-20 2024-05-29 2024-02-24 04:00:00

# %%
diff=pd.Timedelta(weeks=7,days=7,hours=7,minutes=7,seconds=7)
df['difference']=df['DataTime4']-diff
df
# Out:
#    DataTime4     100day            100hours          difference
# 0 2024-02-17 2024-05-26 2024-02-21 04:00:00 2023-12-22 16:52:53
# 1 2024-02-18 2024-05-27 2024-02-22 04:00:00 2023-12-23 16:52:53
# 2 2024-02-19 2024-05-28 2024-02-23 04:00:00 2023-12-24 16:52:53
# 3 2024-02-20 2024-05-29 2024-02-24 04:00:00 2023-12-25 16:52:53

# %%
diff2=df['100day']-df['100hours']

# %%
df
# Out:
#    DataTime4     100day            100hours          difference  \
# 0 2024-02-17 2024-05-26 2024-02-21 04:00:00 2023-12-22 16:52:53
# 1 2024-02-18 2024-05-27 2024-02-22 04:00:00 2023-12-23 16:52:53
# 2 2024-02-19 2024-05-28 2024-02-23 04:00:00 2023-12-24 16:52:53
# 3 2024-02-20 2024-05-29 2024-02-24 04:00:00 2023-12-25 16:52:53
#
#              diff2
# 0 94 days 20:00:00
# 1 94 days 20:00:00
# 2 94 days 20:00:00
# 3 94 days 20:00:00

# %%
diff2
# Out:
# 0   94 days 20:00:00
# 1   94 days 20:00:00
# 2   94 days 20:00:00
# 3   94 days 20:00:00
# dtype: timedelta64[ns]

# %%
print(diff2.dt.total_seconds())
print(diff2.dt.total_seconds()/60)
# Out:
# 0    8193600.0
# 1    8193600.0
# 2    8193600.0
# 3    8193600.0
# dtype: float64
# 0    136560.0
# 1    136560.0
# 2    136560.0
# 3    136560.0
# dtype: float64

# %%
print(diff2.dt.days)
# Out:
# 0    94
# 1    94
# 2    94
# 3    94
# dtype: int64

# %%
print(diff2.dt.total_seconds())
print(diff2.dt.seconds)
# Out:
# 0    8193600.0
# 1    8193600.0
# 2    8193600.0
# 3    8193600.0
# dtype: float64
# 0    72000
# 1    72000
# 2    72000
# 3    72000
# dtype: int32

# %%
min=5.41

# %%
print(int(min),'분')
# Out:
# 5 분

# %%
print(0.41*60,'초')
# Out:
# 24.599999999999998 초

# %%
import pandas as pd
appetizer=pd.DataFrame({
    'Menu':['Salad','Soup','Bread'],
    'Price':[5000,3000,2000]
})

# %%
appetizer
# Out:
#     Menu  Price
# 0  Salad   5000
# 1   Soup   3000
# 2  Bread   2000

# %%
main=pd.DataFrame({
    'Menu':['Steak','Pasta','Chicken'],
    'Price':[15000,12000,10000]
})

# %%
main
# Out:
#       Menu  Price
# 0    Steak  15000
# 1    Pasta  12000
# 2  Chicken  10000

# %%
print(appetizer)
print(main)
# Out:
#     Menu  Price
# 0  Salad   5000
# 1   Soup   3000
# 2  Bread   2000
#       Menu  Price
# 0    Steak  15000
# 1    Pasta  12000
# 2  Chicken  10000

# %%
full_menu=pd.concat([appetizer,main],ignore_index=True)

# %%
full_menu
# Out:
#       Menu  Price
# 0    Salad   5000
# 1     Soup   3000
# 2    Bread   2000
# 3    Steak  15000
# 4    Pasta  12000
# 5  Chicken  10000

# %%
full_menu=pd.concat([appetizer,main],axis=1)

# %%
full_menu
# Out:
#     Menu  Price     Menu  Price
# 0  Salad   5000    Steak  15000
# 1   Soup   3000    Pasta  12000
# 2  Bread   2000  Chicken  10000

# %%
price=pd.DataFrame({
    'Menu':['Salad','Soup','Steak','Pasta'],
    'Price':[5000,3000,15000,12000]
})

# %%
price
# Out:
#     Menu  Price
# 0  Salad   5000
# 1   Soup   3000
# 2  Steak  15000
# 3  Pasta  12000

# %%
cal=pd.DataFrame({
    'Menu':['Soup','Steak','Pasta','Salad'],
    'Calories':[100,500,400,150]
})

# %%
cal
# Out:
#     Menu  Calories
# 0   Soup       100
# 1  Steak       500
# 2  Pasta       400
# 3  Salad       150

# %%
menu_info=pd.merge(price,cal,on='Menu')

# %%
menu_info
# Out:
#     Menu  Price  Calories
# 0  Salad   5000       150
# 1   Soup   3000       100
# 2  Steak  15000       500
# 3  Pasta  12000       400

# %%
import pandas as pd

# %%
data={'이름':['서우','다인','채아','예담','종현','태헌'],
      '부서':['개발','기획','개발','기획','개발','기획'],
      '급여':[3000,3200,3100,3300,2900,3100]}

# %%
data
# Out:
# {'이름': ['서우', '다인', '채아', '예담', '종현', '태헌'],
#  '부서': ['개발', '기획', '개발', '기획', '개발', '기획'],
#  '급여': [3000, 3200, 3100, 3300, 2900, 3100]}

# %%
pd.DataFrame(data)
# Out:
#    이름  부서    급여
# 0  서우  개발  3000
# 1  다인  기획  3200
# 2  채아  개발  3100
# 3  예담  기획  3300
# 4  종현  개발  2900
# 5  태헌  기획  3100

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    이름  부서    급여
# 0  서우  개발  3000
# 1  다인  기획  3200
# 2  채아  개발  3100
# 3  예담  기획  3300
# 4  종현  개발  2900
# 5  태헌  기획  3100

# %%
print('[원본데이터]')
print(df)
# Out:
# [원본데이터]
#    이름  부서    급여
# 0  서우  개발  3000
# 1  다인  기획  3200
# 2  채아  개발  3100
# 3  예담  기획  3300
# 4  종현  개발  2900
# 5  태헌  기획  3100

# %%
pt=df.pivot_table(index='부서',values='급여',aggfunc='mean')

# %%
print('|n [부서별 평균 급여]')
print(pt)
# Out:
# |n [부서별 평균 급여]
#         급여
# 부서
# 개발  3000.0
# 기획  3200.0

# %%
data={'부서':['개발','기획','기획','기획','개발','개발'],
      '직급':['대리','과장','대리','과장','대리','과장'],
      '급여':[3000,4000,3200,4200,3500,4500]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    부서  직급    급여
# 0  개발  대리  3000
# 1  기획  과장  4000
# 2  기획  대리  3200
# 3  기획  과장  4200
# 4  개발  대리  3500
# 5  개발  과장  4500

# %%
print('[원본데이터]')
print(df)
# Out:
# [원본데이터]
#    부서  직급    급여
# 0  개발  대리  3000
# 1  기획  과장  4000
# 2  기획  대리  3200
# 3  기획  과장  4200
# 4  개발  대리  3500
# 5  개발  과장  4500

# %%
pt=df.pivot_table(index='부서',columns='직급',values='급여',aggfunc='mean')

# %%
pt
# Out:
# 직급      과장      대리
# 부서
# 개발  4500.0  3250.0
# 기획  4100.0  3200.0

# %%
import pandas as pd
df=pd.DataFrame({
    '구분':['전자','전자','전자','전자','전자','가전','가전','가전','가전'],
    '유형':['일반','일반','일반','특수','특수','일반','일반','특수','특수'],
    '크기':['소형','대형','대형','소형','소형','대형','소형','소형','대형'],
    '수량':[1,2,2,3,3,4,5,6,7,],
    '금액':[2,4,5,5,6,6,8,9,9,]
})

# %%
df
# Out:
#    구분  유형  크기  수량  금액
# 0  전자  일반  소형   1   2
# 1  전자  일반  대형   2   4
# 2  전자  일반  대형   2   5
# 3  전자  특수  소형   3   5
# 4  전자  특수  소형   3   6
# 5  가전  일반  대형   4   6
# 6  가전  일반  소형   5   8
# 7  가전  특수  소형   6   9
# 8  가전  특수  대형   7   9

# %%
pt=df.pivot_table(index=['구분','유형'],columns=['크기'],values=['수량'],aggfunc='sum',fill_value=0)

# %%
pt
# Out:
#       수량
# 크기    대형 소형
# 구분 유형
# 가전 일반  4  5
#    특수  7  6
# 전자 일반  4  1
#    특수  0  6

# %%
pt=df.pivot_table(index=['구분','크기'],values=['수량','금액'],aggfunc={'수량':'mean','금액':'mean'})

# %%
pt
# Out:
#              금액        수량
# 구분 크기
# 가전 대형  7.500000  5.500000
#    소형  8.500000  5.500000
# 전자 대형  4.500000  2.000000
#    소형  4.333333  2.333333
