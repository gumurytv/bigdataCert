# %% [markdown]
# <a href="https://colab.research.google.com/github/gumurytv/bigdataCert/blob/main/PART1_%EC%B1%95%ED%84%B002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
menu=pd.Series(['비빔밥','김치찌개','된장찌개'])
menu
# Out:
# 0     비빔밥
# 1    김치찌개
# 2    된장찌개
# dtype: object

# %%
price=pd.Series([10000,9000,8000])
price
# Out:
# 0    10000
# 1     9000
# 2     8000
# dtype: int64

# %%
pd.DataFrame({
    '메뉴':menu,
    '가격':price
})
# Out:
#      메뉴     가격
# 0   비빔밥  10000
# 1  김치찌개   9000
# 2  된장찌개   8000

# %%
df=pd.DataFrame({
    '메뉴':['비빔밥','김치찌개','된장찌개'],
    '가격':[10000,9000,8000],
    '원산지':['국내산','국내산','국내산']})
df
# Out:
#      메뉴     가격  원산지
# 0   비빔밥  10000  국내산
# 1  김치찌개   9000  국내산
# 2  된장찌개   8000  국내산

# %%
df['메뉴']
# Out:
# 0     비빔밥
# 1    김치찌개
# 2    된장찌개
# Name: 메뉴, dtype: object

# %%
df[['메뉴']]
# Out:
#      메뉴
# 0   비빔밥
# 1  김치찌개
# 2  된장찌개

# %%
df[['메뉴','가격']]
# Out:
#      메뉴     가격
# 0   비빔밥  10000
# 1  김치찌개   9000
# 2  된장찌개   8000

# %%
cols=['메뉴','가격']

# %%
df[cols]
# Out:
#      메뉴     가격
# 0   비빔밥  10000
# 1  김치찌개   9000
# 2  된장찌개   8000

# %%
print('df:',type(df))
print('df:',type(df['가격']))
print('df:',type(df[['가격']]))
# Out:
# df: <class 'pandas.core.frame.DataFrame'>
# df: <class 'pandas.core.series.Series'>
# df: <class 'pandas.core.frame.DataFrame'>

# %%
df=pd.DataFrame({
    '메뉴':['아메리카노','카페라떼','카페모카','카푸치노','에스프레소','밀크티','녹차'],
    '가격':[4500,5000,5500,5000,4000,5900,5300],
    '칼로리':[10,110,250,110,20,210,0]
})
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
df.to_csv('temp.csv')

# %%
temp_df=pd.read_csv('temp.csv')

# %%
temp_df.head()
# Out:
#    Unnamed: 0     메뉴    가격  칼로리
# 0           0  아메리카노  4500   10
# 1           1   카페라떼  5000  110
# 2           2   카페모카  5500  250
# 3           3   카푸치노  5000  110
# 4           4  에스프레소  4000   20

# %%
df.to_csv('cafe.csv',index=False)

# %%
df=pd.read_csv('cafe.csv')

# %%
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
df.head()
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20

# %%
df.tail
# Out:
# <bound method NDFrame.tail of       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0>

# %%
df.tail()
# Out:
#       메뉴    가격  칼로리
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
df.head(3)
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250

# %%
df.shape
# Out:
# (7, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      int64
#  2   칼로리     7 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 300.0+ bytes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      int64
#  2   칼로리     7 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 300.0+ bytes

# %%
df.corr(numeric_only=True)
# Out:
#            가격       칼로리
# 가격   1.000000  0.713227
# 칼로리  0.713227  1.000000

# %%
df_car=pd.DataFrame({
    'car':['Sedan','SUV','Sedan','SUV','SUV','SUV','Sedan','Sedan','Sedan','Sedan','Sedan'],
    'size':['S','M','S','S','M','M','L','S','S','M','S']})
df_car
# Out:
#       car size
# 0   Sedan    S
# 1     SUV    M
# 2   Sedan    S
# 3     SUV    S
# 4     SUV    M
# 5     SUV    M
# 6   Sedan    L
# 7   Sedan    S
# 8   Sedan    S
# 9   Sedan    M
# 10  Sedan    S

# %%
df_car.nunique()
# Out:
# car     2
# size    3
# dtype: int64

# %%
df_car['car'].unique()
# Out:
# array(['Sedan', 'SUV'], dtype=object)

# %%
print('car:',df_car['car'].unique())
# Out:
# car: ['Sedan' 'SUV']

# %%
df_car['car'].value_counts()
# Out:
# car
# Sedan    7
# SUV      4
# Name: count, dtype: int64

# %%
df_car.describe()
# Out:
#           car size
# count      11   11
# unique      2    3
# top     Sedan    S
# freq        7    6

# %%
df_car.describe()
# Out:
#           car size
# count      11   11
# unique      2    3
# top     Sedan    S
# freq        7    6

# %%
df.describe()
# Out:
#                 가격         칼로리
# count     7.000000    7.000000
# mean   5028.571429  101.428571
# std     631.702160   99.402980
# min    4000.000000    0.000000
# 25%    4750.000000   15.000000
# 50%    5000.000000  110.000000
# 75%    5400.000000  160.000000
# max    5900.000000  250.000000

# %%
df_car.describe(include='O')
# Out:
#           car size
# count      11   11
# unique      2    3
# top     Sedan    S
# freq        7    6

# %%
df.describe(include='O')
# Out:
#            메뉴
# count       7
# unique      7
# top     아메리카노
# freq        1

# %%
data={'메뉴':['아메리카노','카페라떼','카페모카','카푸치노','에스프레소','밀크티','녹차'],
      '가격':[4500.0,5000.0,5500.0,5000.0,4000.0,5900.0,5300.0,],
      '칼로리':['10','110','250','110','20','210','0']}

# %%
df=pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      float64
#  2   칼로리     7 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 300.0+ bytes

# %%
df['가격']=df['가격'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      int64
#  2   칼로리     7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 300.0+ bytes

# %%
df['칼로리']=df['칼로리'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      int64
#  2   칼로리     7 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 300.0+ bytes

# %%
df.head()
# Out:
#       메뉴    가격    칼로리
# 0  아메리카노  4500   10.0
# 1   카페라떼  5000  110.0
# 2   카페모카  5500  250.0
# 3   카푸치노  5000  110.0
# 4  에스프레소  4000   20.0

# %%
df=pd.read_csv('cafe.csv')

# %%
df.head(2)
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110

# %%
df['new']=0

# %%
df.head()
# Out:
#       메뉴    가격  칼로리  new
# 0  아메리카노  4500   10    0
# 1   카페라떼  5000  110    0
# 2   카페모카  5500  250    0
# 3   카푸치노  5000  110    0
# 4  에스프레소  4000   20    0

# %%
discount=0.2
df['할인가']=df['가격']*(1-discount)
df.head()
# Out:
#       메뉴    가격  칼로리  new     할인가
# 0  아메리카노  4500   10    0  3600.0
# 1   카페라떼  5000  110    0  4000.0
# 2   카페모카  5500  250    0  4400.0
# 3   카푸치노  5000  110    0  4000.0
# 4  에스프레소  4000   20    0  3200.0

# %%
df=pd.read_csv('cafe.csv')

# %%
df.head()
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20

# %%
df.drop(1,axis=0,inplace=True)
df.head()
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210

# %%
df=df.drop('가격',axis=1)

# %%
df.head()
# Out:
#       메뉴  칼로리
# 0  아메리카노   10
# 2   카페모카  250
# 3   카푸치노  110
# 4  에스프레소   20
# 5    밀크티  210

# %%
df=pd.read_csv('cafe.csv')

# %%
df.head()
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20

# %%
df.loc[0]
# Out:
# 메뉴     아메리카노
# 가격      4500
# 칼로리       10
# Name: 0, dtype: object

# %%
df.loc[1,'가격']
# Out:
# np.int64(5000)

# %%
df.loc[1,'칼로리']
# Out:
# np.int64(110)

# %%
df.head()
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20

# %%
df.loc[2,'가격':'칼로리']
# Out:
# 가격     5500
# 칼로리     250
# Name: 2, dtype: object

# %%
df.loc[:,'가격']
# Out:
# 0    4500
# 1    5000
# 2    5500
# 3    5000
# 4    4000
# 5    5900
# 6    5300
# Name: 가격, dtype: int64

# %%
df.loc[:,'가격']
# Out:
# 0    4500
# 1    5000
# 2    5500
# 3    5000
# 4    4000
# 5    5900
# 6    5300
# Name: 가격, dtype: int64

# %%
df.head()
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20

# %%
df=pd.read_csv('cafe.csv')

# %%
df.head()
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20

# %%
import numpy as np

# %%
df['원산지']=np.nan

# %%
df.head()
# Out:
#       메뉴    가격  칼로리  원산지
# 0  아메리카노  4500   10  NaN
# 1   카페라떼  5000  110  NaN
# 2   카페모카  5500  250  NaN
# 3   카푸치노  5000  110  NaN
# 4  에스프레소  4000   20  NaN

# %%
df.loc[0,'원산지']='콜롬비아'
df.loc[2:3,'원산지']='과테말라'
# Out:
# /tmp/ipykernel_294/3061043173.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '콜롬비아' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0,'원산지']='콜롬비아'

# %%
df.head()
# Out:
#       메뉴    가격  칼로리   원산지
# 0  아메리카노  4500   10  콜롬비아
# 1   카페라떼  5000  110   NaN
# 2   카페모카  5500  250  과테말라
# 3   카푸치노  5000  110  과테말라
# 4  에스프레소  4000   20   NaN

# %%
df.loc['시즌']=['크리스마스라떼',6000,300,'한국']

# %%
df.tail()
# Out:
#          메뉴    가격  칼로리   원산지
# 3      카푸치노  5000  110  과테말라
# 4     에스프레소  4000   20   NaN
# 5       밀크티  5900  210   NaN
# 6        녹차  5300    0   NaN
# 시즌  크리스마스라떼  6000  300    한국

# %%
df.loc[7]={'메뉴':'딴짓커피','가격':2000,'칼로리':20}

# %%
df.tail(3)
# Out:
#          메뉴    가격  칼로리  원산지
# 6        녹차  5300    0  NaN
# 시즌  크리스마스라떼  6000  300   한국
# 7      딴짓커피  2000   20  NaN

# %%
df=df.drop('시즌',axis=0)

# %%
df
# Out:
#       메뉴    가격  칼로리   원산지
# 0  아메리카노  4500   10  콜롬비아
# 1   카페라떼  5000  110   NaN
# 2   카페모카  5500  250  과테말라
# 3   카푸치노  5000  110  과테말라
# 4  에스프레소  4000   20   NaN
# 5    밀크티  5900  210   NaN
# 6     녹차  5300    0   NaN
# 7   딴짓커피  2000   20   NaN

# %%
df.to_csv('cafe2.csv',index=False)

# %%
df=pd.read_csv('cafe2.csv')

# %%
df.sort_index(ascending=False)
# Out:
#       메뉴    가격  칼로리   원산지
# 7   딴짓커피  2000   20   NaN
# 6     녹차  5300    0   NaN
# 5    밀크티  5900  210   NaN
# 4  에스프레소  4000   20   NaN
# 3   카푸치노  5000  110  과테말라
# 2   카페모카  5500  250  과테말라
# 1   카페라떼  5000  110   NaN
# 0  아메리카노  4500   10  콜롬비아

# %%
df.sort_values('메뉴',ascending=False)
# Out:
#       메뉴    가격  칼로리   원산지
# 3   카푸치노  5000  110  과테말라
# 2   카페모카  5500  250  과테말라
# 1   카페라떼  5000  110   NaN
# 4  에스프레소  4000   20   NaN
# 0  아메리카노  4500   10  콜롬비아
# 5    밀크티  5900  210   NaN
# 7   딴짓커피  2000   20   NaN
# 6     녹차  5300    0   NaN

# %%
df.sort_values(['가격','메뉴'],ascending=[False,True],inplace=True)

# %%
df.head()
# Out:
#      메뉴    가격  칼로리   원산지
# 5   밀크티  5900  210   NaN
# 2  카페모카  5500  250  과테말라
# 6    녹차  5300    0   NaN
# 1  카페라떼  5000  110   NaN
# 3  카푸치노  5000  110  과테말라

# %%
df.reset_index(drop=True)
# Out:
#       메뉴    가격  칼로리   원산지
# 0    밀크티  5900  210   NaN
# 1   카페모카  5500  250  과테말라
# 2     녹차  5300    0   NaN
# 3   카페라떼  5000  110   NaN
# 4   카푸치노  5000  110  과테말라
# 5  아메리카노  4500   10  콜롬비아
# 6  에스프레소  4000   20   NaN
# 7   딴짓커피  2000   20   NaN

# %%
df=pd.read_csv('cafe2.csv')

# %%
df.head()
# Out:
#       메뉴    가격  칼로리   원산지
# 0  아메리카노  4500   10  콜롬비아
# 1   카페라떼  5000  110   NaN
# 2   카페모카  5500  250  과테말라
# 3   카푸치노  5000  110  과테말라
# 4  에스프레소  4000   20   NaN

# %%
df['칼로리']<50
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6     True
# 7     True
# Name: 칼로리, dtype: bool

# %%
cond=df['칼로리']<50

# %%
df[cond]
# Out:
#       메뉴    가격  칼로리   원산지
# 0  아메리카노  4500   10  콜롬비아
# 4  에스프레소  4000   20   NaN
# 6     녹차  5300    0   NaN
# 7   딴짓커피  2000   20   NaN

# %%
df[~cond]
# Out:
#      메뉴    가격  칼로리   원산지
# 1  카페라떼  5000  110   NaN
# 2  카페모카  5500  250  과테말라
# 3  카푸치노  5000  110  과테말라
# 5   밀크티  5900  210   NaN

# %%
df[~cond]
# Out:
#      메뉴    가격  칼로리   원산지
# 1  카페라떼  5000  110   NaN
# 2  카페모카  5500  250  과테말라
# 3  카푸치노  5000  110  과테말라
# 5   밀크티  5900  210   NaN

# %%
df=pd.read_csv('cafe2.csv')

# %%
df.head()
# Out:
#       메뉴    가격  칼로리   원산지
# 0  아메리카노  4500   10  콜롬비아
# 1   카페라떼  5000  110   NaN
# 2   카페모카  5500  250  과테말라
# 3   카푸치노  5000  110  과테말라
# 4  에스프레소  4000   20   NaN

# %%
df['칼로리']<50
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6     True
# 7     True
# Name: 칼로리, dtype: bool

# %%
df['칼로리']
# Out:
# 0     10
# 1    110
# 2    250
# 3    110
# 4     20
# 5    210
# 6      0
# 7     20
# Name: 칼로리, dtype: int64

# %%
cond1=df['가격']>=5000
cond2=df['칼로리']>100
df[cond1&cond2]
# Out:
#      메뉴    가격  칼로리   원산지
# 1  카페라떼  5000  110   NaN
# 2  카페모카  5500  250  과테말라
# 3  카푸치노  5000  110  과테말라
# 5   밀크티  5900  210   NaN

# %%
df[cond1|cond2]
# Out:
#      메뉴    가격  칼로리   원산지
# 1  카페라떼  5000  110   NaN
# 2  카페모카  5500  250  과테말라
# 3  카푸치노  5000  110  과테말라
# 5   밀크티  5900  210   NaN
# 6    녹차  5300    0   NaN

# %%
df[df['원산지']=='과테말라']
# Out:
#      메뉴    가격  칼로리   원산지
# 2  카페모카  5500  250  과테말라
# 3  카푸치노  5000  110  과테말라

# %%
cond1=df['원산지']=='과테말라'
cond2=df['가격']<=5000

# %%
df[cond1&cond2]
# Out:
#      메뉴    가격  칼로리   원산지
# 3  카푸치노  5000  110  과테말라

# %%
df['메뉴'].isin(['녹차'])
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# Name: 메뉴, dtype: bool

# %%
cond=df['메뉴'].isin(['녹차'])

# %%
cond
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# Name: 메뉴, dtype: bool

# %%
df[cond]
# Out:
#    메뉴    가격  칼로리  원산지
# 6  녹차  5300    0  NaN

# %%
box=['녹차','카푸치노','카페라떼']

# %%
cond=df['메뉴'].isin(box)

# %%
cond
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7    False
# Name: 메뉴, dtype: bool

# %%
df[cond]
# Out:
#      메뉴    가격  칼로리   원산지
# 1  카페라떼  5000  110   NaN
# 3  카푸치노  5000  110  과테말라
# 6    녹차  5300    0   NaN

# %%
df=pd.read_csv('cafe2.csv')

# %%
df
# Out:
#       메뉴    가격  칼로리   원산지
# 0  아메리카노  4500   10  콜롬비아
# 1   카페라떼  5000  110   NaN
# 2   카페모카  5500  250  과테말라
# 3   카푸치노  5000  110  과테말라
# 4  에스프레소  4000   20   NaN
# 5    밀크티  5900  210   NaN
# 6     녹차  5300    0   NaN
# 7   딴짓커피  2000   20   NaN

# %%
df.isnull()
# Out:
#       메뉴     가격    칼로리    원산지
# 0  False  False  False  False
# 1  False  False  False   True
# 2  False  False  False  False
# 3  False  False  False  False
# 4  False  False  False   True
# 5  False  False  False   True
# 6  False  False  False   True
# 7  False  False  False   True

# %%
df.isnull().sum()
# Out:
# 메뉴     0
# 가격     0
# 칼로리    0
# 원산지    5
# dtype: int64

# %%
df.isna().sum()
# Out:
# 메뉴     0
# 가격     0
# 칼로리    0
# 원산지    5
# dtype: int64

# %%
df['원산지'].fillna('코스타리카',inplace=True)
# Out:
# /tmp/ipykernel_294/3660102855.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['원산지'].fillna('코스타리카',inplace=True)

# %%
df
# Out:
#       메뉴    가격  칼로리    원산지
# 0  아메리카노  4500   10   콜롬비아
# 1   카페라떼  5000  110  코스타리카
# 2   카페모카  5500  250   과테말라
# 3   카푸치노  5000  110   과테말라
# 4  에스프레소  4000   20  코스타리카
# 5    밀크티  5900  210  코스타리카
# 6     녹차  5300    0  코스타리카
# 7   딴짓커피  2000   20  코스타리카

# %%
df.to_csv('cafe3.csv',index=False)

# %%
df=pd.read_csv('cafe3.csv')

# %%
df
# Out:
#       메뉴    가격  칼로리    원산지
# 0  아메리카노  4500   10   콜롬비아
# 1   카페라떼  5000  110  코스타리카
# 2   카페모카  5500  250   과테말라
# 3   카푸치노  5000  110   과테말라
# 4  에스프레소  4000   20  코스타리카
# 5    밀크티  5900  210  코스타리카
# 6     녹차  5300    0  코스타리카
# 7   딴짓커피  2000   20  코스타리카

# %%
df.replace('아메리카노','룽고',inplace=True)
df.replace('녹차','그린티',inplace=True)
df
# Out:
#       메뉴    가격  칼로리    원산지
# 0     룽고  4500   10   콜롬비아
# 1   카페라떼  5000  110  코스타리카
# 2   카페모카  5500  250   과테말라
# 3   카푸치노  5000  110   과테말라
# 4  에스프레소  4000   20  코스타리카
# 5    밀크티  5900  210  코스타리카
# 6    그린티  5300    0  코스타리카
# 7   딴짓커피  2000   20  코스타리카

# %%
change={'룽고':'아메리카노','그린티':'녹차'}
df.replace(change,inplace=True)
df
# Out:
#       메뉴    가격  칼로리    원산지
# 0  아메리카노  4500   10   콜롬비아
# 1   카페라떼  5000  110  코스타리카
# 2   카페모카  5500  250   과테말라
# 3   카푸치노  5000  110   과테말라
# 4  에스프레소  4000   20  코스타리카
# 5    밀크티  5900  210  코스타리카
# 6     녹차  5300    0  코스타리카
# 7   딴짓커피  2000   20  코스타리카

# %%
df.loc[6,'원산지']='대한민국'

# %%
df
# Out:
#       메뉴    가격  칼로리    원산지
# 0  아메리카노  4500   10   콜롬비아
# 1   카페라떼  5000  110  코스타리카
# 2   카페모카  5500  250   과테말라
# 3   카푸치노  5000  110   과테말라
# 4  에스프레소  4000   20  코스타리카
# 5    밀크티  5900  210  코스타리카
# 6     녹차  5300    0   대한민국
# 7   딴짓커피  2000   20  코스타리카

# %%
df.loc[1:2,'이벤트가']=1000

# %%
df
# Out:
#       메뉴    가격  칼로리    원산지    이벤트가
# 0  아메리카노  4500   10   콜롬비아     NaN
# 1   카페라떼  5000  110  코스타리카  1000.0
# 2   카페모카  5500  250   과테말라  1000.0
# 3   카푸치노  5000  110   과테말라     NaN
# 4  에스프레소  4000   20  코스타리카     NaN
# 5    밀크티  5900  210  코스타리카     NaN
# 6     녹차  5300    0   대한민국     NaN
# 7   딴짓커피  2000   20  코스타리카     NaN

# %%
df.to_csv('cafe4.csv',index=False)

# %%
import pandas as pd

# %%
df=pd.DataFrame({'A':['데이터분석','기본 학습서','퇴근 후 열공'],
                 'B':[10,20,30],
                 'C':['ab cd','AB CD','ab cd']})

# %%
df
# Out:
#          A   B      C
# 0    데이터분석  10  ab cd
# 1   기본 학습서  20  AB CD
# 2  퇴근 후 열공  30  ab cd

# %%
df['A']=df['A'].str.replace('분석','시각화')

# %%
df
# Out:
#          A   B      C
# 0   데이터시각화  10  ab cd
# 1   기본 학습서  20  AB CD
# 2  퇴근 후 열공  30  ab cd

# %%
df['B']=df['B'].replace(10,100)

# %%
df
# Out:
#          A    B      C
# 0   데이터시각화  100  ab cd
# 1   기본 학습서   20  AB CD
# 2  퇴근 후 열공   30  ab cd

# %%
df.head()
# Out:
#          A    B      C
# 0   데이터시각화  100  ab cd
# 1   기본 학습서   20  AB CD
# 2  퇴근 후 열공   30  ab cd

# %%
df['A'].str.split()
# Out:
# 0       [데이터시각화]
# 1      [기본, 학습서]
# 2    [퇴근, 후, 열공]
# Name: A, dtype: object

# %%
df['A'].str.split()[1]
# Out:
# ['기본', '학습서']

# %%
df['D']=df['A'].str.split().str[0]

# %%
df
# Out:
#          A    B      C       D
# 0   데이터시각화  100  ab cd  데이터시각화
# 1   기본 학습서   20  AB CD      기본
# 2  퇴근 후 열공   30  ab cd      퇴근

# %%
df['A'].str.contains('기본')
# Out:
# 0    False
# 1     True
# 2    False
# Name: A, dtype: bool

# %%
df['기본포함유무']=df['A'].str.contains('기본')

# %%
df
# Out:
#          A    B      C       D  기본포함유무
# 0   데이터시각화  100  ab cd  데이터시각화   False
# 1   기본 학습서   20  AB CD      기본    True
# 2  퇴근 후 열공   30  ab cd      퇴근   False

# %%
df['문자길이']=df['A'].str.len()

# %%
df
# Out:
#          A    B      C       D  기본포함유무  문자길이
# 0   데이터시각화  100  ab cd  데이터시각화   False     6
# 1   기본 학습서   20  AB CD      기본    True     6
# 2  퇴근 후 열공   30  ab cd      퇴근   False     7

# %%
'AB cd'=='ab CD'
# Out:
# False

# %%
df['C']=df['C'].str.lower()

# %%
df
# Out:
#          A    B      C       D  기본포함유무  문자길이
# 0   데이터시각화  100  ab cd  데이터시각화   False     6
# 1   기본 학습서   20  ab cd      기본    True     6
# 2  퇴근 후 열공   30  ab cd      퇴근   False     7

# %%
df['C']=df['C'].str.upper()

# %%
df
# Out:
#          A    B      C       D  기본포함유무  문자길이
# 0   데이터시각화  100  AB CD  데이터시각화   False     6
# 1   기본 학습서   20  AB CD      기본    True     6
# 2  퇴근 후 열공   30  AB CD      퇴근   False     7

# %%
df['C']=='AB CD'
# Out:
# 0    True
# 1    True
# 2    True
# Name: C, dtype: bool

# %%
df['C']=df['C'].str.lower()
df['C']=df['C'].str.replace(" ","")

# %%
df
# Out:
#          A    B     C       D  기본포함유무  문자길이
# 0   데이터시각화  100  abcd  데이터시각화   False     6
# 1   기본 학습서   20  abcd      기본    True     6
# 2  퇴근 후 열공   30  abcd      퇴근   False     7

# %%
df['C']=df['C'].str.strip()

# %%
df
# Out:
#          A    B     C       D  기본포함유무  문자길이
# 0   데이터시각화  100  abcd  데이터시각화   False     6
# 1   기본 학습서   20  abcd      기본    True     6
# 2  퇴근 후 열공   30  abcd      퇴근   False     7

# %%
df['C']=df['C'].str[1:3]

# %%
df
# Out:
#          A    B   C       D  기본포함유무  문자길이
# 0   데이터시각화  100  bc  데이터시각화   False     6
# 1   기본 학습서   20  bc      기본    True     6
# 2  퇴근 후 열공   30  bc      퇴근   False     7

# %%
df['C'][0:3]
# Out:
# 0    bc
# 1    bc
# 2    bc
# Name: C, dtype: object

# %%
df=pd.read_csv('cafe4.csv')

# %%
df
# Out:
#       메뉴    가격  칼로리    원산지    이벤트가
# 0  아메리카노  4500   10   콜롬비아     NaN
# 1   카페라떼  5000  110  코스타리카  1000.0
# 2   카페모카  5500  250   과테말라  1000.0
# 3   카푸치노  5000  110   과테말라     NaN
# 4  에스프레소  4000   20  코스타리카     NaN
# 5    밀크티  5900  210  코스타리카     NaN
# 6     녹차  5300    0   대한민국     NaN
# 7   딴짓커피  2000   20  코스타리카     NaN

# %%
df.shape[0]
# Out:
# 8

# %%
len(df)
# Out:
# 8

# %%
cond=df['가격']>5000

# %%
sum(cond)
# Out:
# 3

# %%
sum(cond)
# Out:
# 3

# %%
len(df[cond])
# Out:
# 3

# %%
df.sum(numeric_only=True)
# Out:
# 가격      37200.0
# 칼로리       730.0
# 이벤트가     2000.0
# dtype: float64

# %%
df.T
# Out:
#           0       1       2     3      4      5     6      7
# 메뉴    아메리카노    카페라떼    카페모카  카푸치노  에스프레소    밀크티    녹차   딴짓커피
# 가격     4500    5000    5500  5000   4000   5900  5300   2000
# 칼로리      10     110     250   110     20    210     0     20
# 원산지    콜롬비아   코스타리카    과테말라  과테말라  코스타리카  코스타리카  대한민국  코스타리카
# 이벤트가    NaN  1000.0  1000.0   NaN    NaN    NaN   NaN    NaN

# %%
df
# Out:
#       메뉴    가격  칼로리    원산지    이벤트가
# 0  아메리카노  4500   10   콜롬비아     NaN
# 1   카페라떼  5000  110  코스타리카  1000.0
# 2   카페모카  5500  250   과테말라  1000.0
# 3   카푸치노  5000  110   과테말라     NaN
# 4  에스프레소  4000   20  코스타리카     NaN
# 5    밀크티  5900  210  코스타리카     NaN
# 6     녹차  5300    0   대한민국     NaN
# 7   딴짓커피  2000   20  코스타리카     NaN

# %%
df.T
# Out:
#           0       1       2     3      4      5     6      7
# 메뉴    아메리카노    카페라떼    카페모카  카푸치노  에스프레소    밀크티    녹차   딴짓커피
# 가격     4500    5000    5500  5000   4000   5900  5300   2000
# 칼로리      10     110     250   110     20    210     0     20
# 원산지    콜롬비아   코스타리카    과테말라  과테말라  코스타리카  코스타리카  대한민국  코스타리카
# 이벤트가    NaN  1000.0  1000.0   NaN    NaN    NaN   NaN    NaN

# %%
df=df.T

# %%
df
# Out:
#           0       1       2     3      4      5     6      7
# 메뉴    아메리카노    카페라떼    카페모카  카푸치노  에스프레소    밀크티    녹차   딴짓커피
# 가격     4500    5000    5500  5000   4000   5900  5300   2000
# 칼로리      10     110     250   110     20    210     0     20
# 원산지    콜롬비아   코스타리카    과테말라  과테말라  코스타리카  코스타리카  대한민국  코스타리카
# 이벤트가    NaN  1000.0  1000.0   NaN    NaN    NaN   NaN    NaN

# %%
df.sum(axis=1,numeric_only=True)
# Out:
# 메뉴      0.0
# 가격      0.0
# 칼로리     0.0
# 원산지     0.0
# 이벤트가    0.0
# dtype: float64

# %%
df['가격'].max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_294/3616303246.py in <cell line: 0>()
# ----> 1 df['가격'].max()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     415                 raise KeyError(key) from err
#     416         if isinstance(key, Hashable):
# --> 417             raise KeyError(key)
#     418         self._check_indexing_error(key)
#     419         raise KeyError(key)
#
# KeyError: '가격'

# %%
df
# Out:
#           0       1       2     3      4      5     6      7
# 메뉴    아메리카노    카페라떼    카페모카  카푸치노  에스프레소    밀크티    녹차   딴짓커피
# 가격     4500    5000    5500  5000   4000   5900  5300   2000
# 칼로리      10     110     250   110     20    210     0     20
# 원산지    콜롬비아   코스타리카    과테말라  과테말라  코스타리카  코스타리카  대한민국  코스타리카
# 이벤트가    NaN  1000.0  1000.0   NaN    NaN    NaN   NaN    NaN

# %%
df=pd.read_csv('cafe4.csv')

# %%
df
# Out:
#       메뉴    가격  칼로리    원산지    이벤트가
# 0  아메리카노  4500   10   콜롬비아     NaN
# 1   카페라떼  5000  110  코스타리카  1000.0
# 2   카페모카  5500  250   과테말라  1000.0
# 3   카푸치노  5000  110   과테말라     NaN
# 4  에스프레소  4000   20  코스타리카     NaN
# 5    밀크티  5900  210  코스타리카     NaN
# 6     녹차  5300    0   대한민국     NaN
# 7   딴짓커피  2000   20  코스타리카     NaN

# %%
df['가격'].max()
# Out:
# 5900

# %%
df['가격'].min()
# Out:
# 2000

# %%
df['가격'].median()
# Out:
# 5000.0

# %%
df['가격'].quantile(0.25)
# Out:
# np.float64(4375.0)

# %%
df['가격'].quantile(0.75)
# Out:
# np.float64(5350.0)

# %%
cond=df['가격']<df['가격'].quantile(0.25)

# %%
cond
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7     True
# Name: 가격, dtype: bool

# %%
sum(cond)
# Out:
# 2

# %%
df[cond]
# Out:
#       메뉴    가격  칼로리    원산지  이벤트가
# 4  에스프레소  4000   20  코스타리카   NaN
# 7   딴짓커피  2000   20  코스타리카   NaN

# %%
df
# Out:
#       메뉴    가격  칼로리    원산지    이벤트가
# 0  아메리카노  4500   10   콜롬비아     NaN
# 1   카페라떼  5000  110  코스타리카  1000.0
# 2   카페모카  5500  250   과테말라  1000.0
# 3   카푸치노  5000  110   과테말라     NaN
# 4  에스프레소  4000   20  코스타리카     NaN
# 5    밀크티  5900  210  코스타리카     NaN
# 6     녹차  5300    0   대한민국     NaN
# 7   딴짓커피  2000   20  코스타리카     NaN

# %%
df[cond]
# Out:
#       메뉴    가격  칼로리    원산지  이벤트가
# 4  에스프레소  4000   20  코스타리카   NaN
# 7   딴짓커피  2000   20  코스타리카   NaN

# %%
cond=df['가격'].quantile(0.75)

# %%
cond
# Out:
# np.float64(5350.0)

# %%
cond=df['가격']>df['가격'].quantile(0.75)

# %%
df[cond]
# Out:
#      메뉴    가격  칼로리    원산지    이벤트가
# 2  카페모카  5500  250   과테말라  1000.0
# 5   밀크티  5900  210  코스타리카     NaN

# %%
df['원산지'].mode()[0]
# Out:
# '코스타리카'

# %%
df
# Out:
#       메뉴    가격  칼로리    원산지    이벤트가
# 0  아메리카노  4500   10   콜롬비아     NaN
# 1   카페라떼  5000  110  코스타리카  1000.0
# 2   카페모카  5500  250   과테말라  1000.0
# 3   카푸치노  5000  110   과테말라     NaN
# 4  에스프레소  4000   20  코스타리카     NaN
# 5    밀크티  5900  210  코스타리카     NaN
# 6     녹차  5300    0   대한민국     NaN
# 7   딴짓커피  2000   20  코스타리카     NaN

# %%
df['가격'].idxmax()
# Out:
# 5

# %%
max_idx=df['가격'].idxmax()

# %%
df.loc[max_idx,'칼로리']
# Out:
# np.int64(210)
