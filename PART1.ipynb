# %% [markdown]
# <a href="https://colab.research.google.com/github/gumurytv/bigdataCert/blob/main/PART1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('안녕! 시나공')
# Out:
# 안녕! 시나공

# %%
print(2024)
# Out:
# 2024

# %%
'길벗은'
'여러분의 합격을 응원합니다'
# Out:
# '여러분의 합격을 응원합니다'

# %%
print('파이썬')
#print('파이썬은 쉽다')
# Out:
# 파이썬

# %%
# print('이책의 저자 김태헌입니다')
print('여러분을 합격의 가장 빠른길로 안내할게요')
#print('믿고 따라와주세요')
# Out:
# 여러분을 합격의 가장 빠른길로 안내할게요

# %%
print(3+2,3*2,4+2,4-1)
# Out:
# 5 6 6 3

# %%
15/4
# Out:
# 3.75

# %%
90/2
# Out:
# 45.0

# %%
15//4
# Out:
# 3

# %%
15%4
# Out:
# 3

# %%
15//4
# Out:
# 3

# %%
15%4
# Out:
# 3

# %%
16%3
# Out:
# 1

# %%
16%5
# Out:
# 1

# %%
16%4
# Out:
# 0

# %%
15%4
# Out:
# 3

# %%
4**2
# Out:
# 16

# %%
16**0.5
# Out:
# 4.0

# %%
25**0.5
# Out:
# 5.0

# %%
4+3*2
# Out:
# 10

# %%
'py'+'thon'
# Out:
# 'python'

# %%
'te'+'st'
# Out:
# 'test'

# %%
'te'+3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-165/2356707442.py in <cell line: 0>()
# ----> 1 'te'+3
#
# TypeError: can only concatenate str (not "int") to str

# %%
'te'+'3'
# Out:
# 'te3'

# %%
type(1)
# Out:
# int

# %%
type(1.1)
# Out:
# float

# %%
type('hello')
# Out:
# str

# %%
type('3')
# Out:
# str

# %%
type(3)
# Out:
# int

# %%
type(3),type('3'),type(3.0)
# Out:
# (int, str, float)

# %%
type(True),type(False)
# Out:
# (bool, bool)

# %%
True+True+False+False
# Out:
# 2

# %%
americano=4500

# %%
americano
# Out:
# 4500

# %%
print(americano)
# Out:
# 4500

# %%
print('americano')
# Out:
# americano

# %%
latte=4500

# %%
americano+latte
# Out:
# 9000

# %%
coffe=americano+latte

# %%
coffe
# Out:
# 9000

# %%
americano
# Out:
# 4500

# %%
americano=americano-latte

# %%
americano
# Out:
# 0

# %%
a,b,c=10,20,30

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
c
# Out:
# 30

# %%
a+b+c
# Out:
# 60

# %%
a=2
b=0.17
a=a+b

# %%
a
# Out:
# 2.17

# %%
type(a)
# Out:
# float

# %%
box=2.17

# %%
str(box)
# Out:
# '2.17'

# %%
int(box)
# Out:
# 2

# %%
점수=86

# %%
if 점수>=90:
  print('A')
elif 점수>=80:
  print('B')
elif 점수>=70:
  print('C')
else:
  print('D')
# Out:
# B

# %%
score=9
if score<10 and score>=5:
  print('score는 5이상,10미만입니다')
else:
  print('score는 5미만,10이상입니다')
# Out:
# score는 5이상,10미만입니다

# %%
a=2
b=0.17
a=a+b

# %%
type(a)
# Out:
# float

# %%
a
# Out:
# 2.17

# %%
type(a)
# Out:
# float

# %%
box=2.17

# %%
print('문자열:',str(box))
print('정수형:',int(box))
# Out:
# 문자열: 2.17
# 정수형: 2

# %%
type(str(box))
# Out:
# str

# %%
box='3.14'

# %%
box=float(box)+0.10

# %%
box
# Out:
# 3.24

# %%
10>5
# Out:
# True

# %%
10>11
# Out:
# False

# %%
10==10
# Out:
# True

# %%
10!=10
# Out:
# False

# %%
a='데이터'
b='수집'
c='데이터'

# %%
a==b
# Out:
# False

# %%
a==c
# Out:
# True

# %%
if False:
  print('실패')

# %%
False
# Out:
# False

# %%
score=10
if score>=10:
  print('스코어는 10보다 크거나 같다')
# Out:
# 스코어는 10보다 크거나 같다

# %%
if score<=10 and score>=5:
  print("스코어는 10과 5 사이에 있다")
else:
  print("그건 아님")
# Out:
# 스코어는 10과 5 사이에 있다

# %%
if score>=10:
  print('A')
elif score>=5:
  print('B')
else:
  print('C')
# Out:
# A

# %%
A=[1,2,3,4,5]

# %%
A[0]
# Out:
# 1

# %%
print(A[1])
# Out:
# 2

# %%
type(A)
# Out:
# list

# %%
A=['시나공','데이터','빅데이터']

# %%
A
# Out:
# ['시나공', '데이터', '빅데이터']

# %%
A[2]
# Out:
# '빅데이터'

# %%
A.append('분석')

# %%
A
# Out:
# ['시나공', '데이터', '빅데이터', '분석']

# %%
A.append('기사')

# %%
B=[10,2,11,3,5,9]

# %%
B_sorted=sorted(B)

# %%
B_sorted
# Out:
# [2, 3, 5, 9, 10, 11]

# %%
sorted(A,reverse=True)
# Out:
# ['시나공', '빅데이터', '분석', '데이터', '기사']

# %%
sorted(B,reverse=True)
# Out:
# [11, 10, 9, 5, 3, 2]

# %%
sorted(A)
# Out:
# ['기사', '데이터', '분석', '빅데이터', '시나공']

# %%
sorted(A,reverse=True)
# Out:
# ['시나공', '빅데이터', '분석', '데이터', '기사']

# %%
sorted(A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1051/2669374901.py in <cell line: 0>()
# ----> 1 sorted(A)
#
# NameError: name 'A' is not defined

# %%
dictbox={'name':'쿼카','level':5}

# %%
dictbox
# Out:
# {'name': '쿼카', 'level': 5}

# %%
name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1051/3474671970.py in <cell line: 0>()
# ----> 1 name
#
# NameError: name 'name' is not defined

# %%
type(dictbox)
# Out:
# dict

# %%
dictbox['name']
# Out:
# '쿼카'

# %%
dictbox['level']
# Out:
# 5

# %%
dictbox['level']=6

# %%
dictbox['level']
# Out:
# 6

# %%
dictbox.keys()
# Out:
# dict_keys(['name', 'level'])

# %%
dictbox.keys()
# Out:
# dict_keys(['name', 'level'])

# %%
dictbox.values()
# Out:
# dict_values(['쿼카', 6])

# %%
dictbox
# Out:
# {'name': '쿼카', 'level': 6}

# %%
dictbox.items()
# Out:
# dict_items([('name', '쿼카'), ('level', 6)])

# %%
dict.items()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1051/2147715289.py in <cell line: 0>()
# ----> 1 dict.items()
#
# TypeError: unbound method dict.items() needs an argument

# %%
ditcbox.items()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1051/4033865196.py in <cell line: 0>()
# ----> 1 ditcbox.items()
#
# NameError: name 'ditcbox' is not defined

# %%
list(dictbox.values())
# Out:
# ['쿼카', 6]

# %%
dictbox
# Out:
# {'name': '쿼카', 'level': 6}

# %%
dictbox
# Out:
# {'name': '쿼카', 'level': 6}

# %%
dictbox.values()
# Out:
# dict_values(['쿼카', 6])

# %%
dictbox.keys()
# Out:
# dict_keys(['name', 'level'])

# %%
a='합격맛집'
b='길벗'
c='출판사'

dictbox={'닉네임':a,c:b}

# %%
dictbox
# Out:
# {'닉네임': '합격맛집', '출판사': '길벗'}

# %%
listbox1=['딴짓분식','딴짓카페']
listbox2=[4.8,4.9]

dictbox={'가게':listbox1,'평점':listbox2}
dictbox
# Out:
# {'가게': ['딴짓분식', '딴짓카페'], '평점': [4.8, 4.9]}

# %%
list=[2,4,6,8,10]

# %%
list[0]
# Out:
# 2

# %%
list[-1]
# Out:
# 10

# %%
list[0:3]
# Out:
# [2, 4, 6]

# %%
list[0:2]
# Out:
# [2, 4]

# %%
list[1:]
# Out:
# [4, 6, 8, 10]

# %%
list[:3]
# Out:
# [2, 4, 6]

# %%
list[:2]
# Out:
# [2, 4]

# %%
list[::2]
# Out:
# [2, 6, 10]

# %%
list[1:3]=[10,30]

# %%
list
# Out:
# [2, 10, 30, 8, 10]

# %%
dictbox2={'사과':'원숭이','바나나':'기차'}

# %%
dictbox2
# Out:
# {'사과': '원숭이', '바나나': '기차'}

# %%
dictbix.values()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1051/3139006486.py in <cell line: 0>()
# ----> 1 dictbix.values()
#
# NameError: name 'dictbix' is not defined

# %%
dictbox2.values()
# Out:
# dict_values(['원숭이', '기차'])

# %%
dictbox2.keys()
# Out:
# dict_keys(['사과', '바나나'])

# %%
[value for value in dictbox2.values()]
# Out:
# ['원숭이', '기차']

# %%
list
# Out:
# [2, 10, 30, 8, 10]

# %%
list(dictbox2.values())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1051/2404638318.py in <cell line: 0>()
# ----> 1 list(dictbox2.values())
#
# TypeError: 'list' object is not callable

# %%
dictbox2['바나나']='로케트'

# %%
dictbox2
# Out:
# {'사과': '원숭이', '바나나': '로케트'}

# %%
list=[2,4,5,6,7,10]

# %%
sum(list)
# Out:
# 34

# %%
Boolbox=[True,False,True,False]

# %%
sum(Boolbox)
# Out:
# 2

# %%
max(list)
# Out:
# 10

# %%
min(list)
# Out:
# 2

# %%
len(list)
# Out:
# 6

# %%
round(2.24312132,2)
# Out:
# 2.24

# %%
text='빅데이터 분석기사 파이썬 공부'

# %%
text=text.replace('공부','스터디')

# %%
text
# Out:
# '빅데이터 분석기사 파이썬 스터디'

# %%
text=text.replace({'스터디':'공부'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_631/2080090552.py in <cell line: 0>()
# ----> 1 text=text.replace({'스터디':'공부'})
#
# TypeError: replace expected at least 2 arguments, got 1

# %%
text='안녕하세요! 함께 성장해요'

# %%
text[:2]
# Out:
# '안녕'

# %%
text[7:9]
# Out:
# '함께'

# %%
data='2022-12-25'

# %%
data[5:]
# Out:
# '12-25'

# %%
data2=data.split('-')

# %%
data2
# Out:
# ['2022', '12', '25']

# %%
data3=list(data2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_631/3135804006.py in <cell line: 0>()
# ----> 1 data3=list(data2)
#
# TypeError: 'list' object is not callable

# %%
list(data2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_631/1373350652.py in <cell line: 0>()
# ----> 1 list(data2)
#
# TypeError: 'list' object is not callable

# %%
data2
# Out:
# ['2022', '12', '25']

# %%
list[data2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_631/3934862793.py in <cell line: 0>()
# ----> 1 list[data2]
#
# TypeError: list indices must be integers or slices, not list

# %%
data3 = data2[:]

# %%
data3='2025-12-31'

# %%
list(data3)
# Out:
# ['2', '0', '2', '5', '-', '1', '2', '-', '3', '1']

# %%
listbox=[2,4,6,8,10]

# %%
for item in listbox:
  print(item)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
listbox2=['길벗','시나공','빅분기']
for i in listbox2:
  print(i)
# Out:
# 길벗
# 시나공
# 빅분기

# %%
for i2 in listbox:
  result=i2+1
  print(result)
# Out:
# 3
# 5
# 7
# 9
# 11

# %%
for item in range(5):
  print(item)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
list2=[]

# %%
list23
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3764/4075520380.py in <cell line: 0>()
# ----> 1 list23
#
# NameError: name 'list23' is not defined

# %%
list2
# Out:
# []

# %%
for i3 in range(1,6):
  list2.append(i3)
  print(i3)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
list2
# Out:
# [1, 2, 3, 4, 5]

# %%
listbox=['길벗','시나공','빅분기','분석']

# %%
listbox
# Out:
# ['길벗', '시나공', '빅분기', '분석']

# %%
for index,item in enumerate(listbox):
  print(index,item)
# Out:
# 0 길벗
# 1 시나공
# 2 빅분기
# 3 분석

# %%
def hello():
# Out:
#   File "/tmp/ipykernel_3764/2350046573.py", line 1
#     def hello():
#                 ^
# SyntaxError: incomplete input

# %%
def hello():
  print('안녕하세요!')

# %%
hello()
# Out:
# 안녕하세요!

# %%
hello()
# Out:
# 안녕하세요!

# %%
def hello(name):
  print('hello'+name)

# %%
def plus(x,y):
  print(x+y)

# %%
a=2

# %%
b=3

# %%
plus(a,b)
# Out:
# 5

# %%
def plus(x,y):
  result=x+y
  return result

# %%
plus(a,b)
# Out:
# 8

# %%
a
# Out:
# 5

# %%
b
# Out:
# 3

# %%
listbox=[15,46,78,24,56]
def min_max(data):
  mi=min(data)
  ma=max(data)
  return mi,ma

# %%
min_max(listbox)
# Out:
# (15, 78)

# %%
box=['감사','행복','사랑','성공','긍정','변화','성장','희망']

# %%
len(listbox)
# Out:
# 8

# %%
listbox[0]
# Out:
# '감사'

# %%
listbox[-1]
# Out:
# '희망'

# %%
listbox[0:4]
# Out:
# ['감사', '행복', '사랑', '성공']

# %%
listbox[-2]
# Out:
# '성장'

# %%
listbox[2,4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3764/2324691711.py in <cell line: 0>()
# ----> 1 listbox[2,4]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
box[5]='웃음'

# %%
box
# Out:
# ['감사', '행복', '사랑', '성공', '긍정', '웃음', '성장', '희망']

# %%
cols=['name','age','phone']

# %%
for col in cols:
  print(col)
# Out:
# name
# age
# phone

# %%
def min_max(data):
  result=max(data)-min(data)
  return result

# %%
box2=[15,46,78,24,56]

# %%
min_max(box2)
# Out:
# 63

# %%
def adj(text):
  result=text.replace('여러분','당신')
  return result

# %%
str_data='여러분의 합격을 축하합니다'

# %%
adj(str_data)
# Out:
# '당신의 합격을 축하합니다'
